# %% [markdown]
# This file contains all the function calls in all the notebooks. It is currently updated manually, so it might be a little out of date.

# %% [markdown]
# # numpy
#
# * `numpy.abs`: [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb)
# * `numpy.angle`: [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb)
# * `numpy.arange`: [Aliasing](1_Dynamics/9_Sampled_systems/Aliasing.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb), [Regression](1_Dynamics/7_System_identification/Regression.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [Difference Functions](1_Dynamics/7_System_identification/Difference%20Functions.ipynb)
# * `numpy.array`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb), [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb), [Difference Functions](1_Dynamics/7_System_identification/Difference%20Functions.ipynb)
# * `numpy.asmatrix`: [Eigenvalues and Eigenvectors](2_Control/7_Multivariable_control/Eigenvalues%20and%20Eigenvectors.ipynb), [Regression](1_Dynamics/7_System_identification/Regression.ipynb)
# * `numpy.atleast_2d`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb), [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb)
# * `numpy.bmat`: [Regression](1_Dynamics/7_System_identification/Regression.ipynb)
# * `numpy.concatenate`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb), [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb), [PID controller step responses](2_Control/1_Conventional_feedback_control/PID%20controller%20step%20responses.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb), [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb)
# * `numpy.convolve`: [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb), [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb), [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb)
# * `numpy.cos`: [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb)
# * `numpy.cumsum`: [Noise models](2_Control/6_Discrete_control_and_analysis/Noise%20models.ipynb)
# * `numpy.exp`: [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb), [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb), [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb), [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb), [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb), [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb), [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [Difference Functions](1_Dynamics/7_System_identification/Difference%20Functions.ipynb)
# * `numpy.fft.rfft`: [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb)
# * `numpy.fft.rfftfreq`: [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb)
# * `numpy.hstack`: [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb)
# * `numpy.interp`: [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb), [Read input from file](1_Dynamics/2_Time_domain_simulation/Read%20input%20from%20file.ipynb), [Difference Functions](1_Dynamics/7_System_identification/Difference%20Functions.ipynb)
# * `numpy.linalg.det`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
# * `numpy.linalg.eig`: [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb), [Eigenvalues and Eigenvectors](2_Control/7_Multivariable_control/Eigenvalues%20and%20Eigenvectors.ipynb)
# * `numpy.linalg.inv`: [Regression](1_Dynamics/7_System_identification/Regression.ipynb)
# * `numpy.linalg.lstsq`: [Regression](1_Dynamics/7_System_identification/Regression.ipynb), [Difference Functions](1_Dynamics/7_System_identification/Difference%20Functions.ipynb), [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb)
# * `numpy.linalg.norm`: [Eigenvalues and Eigenvectors](2_Control/7_Multivariable_control/Eigenvalues%20and%20Eigenvectors.ipynb)
# * `numpy.linalg.solve`: [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb)
# * `numpy.linalg.svd`: [Eigenvalues and Eigenvectors](2_Control/7_Multivariable_control/Eigenvalues%20and%20Eigenvectors.ipynb)
# * `numpy.linspace`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb), [Dead time compensation](2_Control/5_Advanced_control_methods/Dead%20time%20compensation.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Control valve design](2_Control/8_Control_Practice/Control%20valve%20design.ipynb), [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb), [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb), [Regression](1_Dynamics/7_System_identification/Regression.ipynb), [Difference Functions](1_Dynamics/7_System_identification/Difference%20Functions.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb), [Aliasing](1_Dynamics/9_Sampled_systems/Aliasing.ipynb), [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb), [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb), [Read input from file](1_Dynamics/2_Time_domain_simulation/Read%20input%20from%20file.ipynb), [Real time simulation](1_Dynamics/6_Multivariable_system_representation/Real%20time%20simulation.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb), [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb), [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb)
# * `numpy.logspace`: [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb), [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb), [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `numpy.matrix`: [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb), [Eigenvalues and Eigenvectors](2_Control/7_Multivariable_control/Eigenvalues%20and%20Eigenvectors.ipynb), [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb)
# * `numpy.maximum`: [Dynamic model parameter estimation](1_Dynamics/7_System_identification/Dynamic%20model%20parameter%20estimation.ipynb)
# * `numpy.ones`: [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb)
# * `numpy.ones_like`: [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [Difference Functions](1_Dynamics/7_System_identification/Difference%20Functions.ipynb)
# * `numpy.polyfit`: [Regression](1_Dynamics/7_System_identification/Regression.ipynb)
# * `numpy.polyval`: [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb), [Regression](1_Dynamics/7_System_identification/Regression.ipynb)
# * `numpy.rad2deg`: [Eigenvalues and Eigenvectors](2_Control/7_Multivariable_control/Eigenvalues%20and%20Eigenvectors.ipynb)
# * `numpy.random.normal`: [Difference Functions](1_Dynamics/7_System_identification/Difference%20Functions.ipynb)
# * `numpy.random.rand`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `numpy.random.randn`: [Noise models](2_Control/6_Discrete_control_and_analysis/Noise%20models.ipynb), [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb), [Dynamic model parameter estimation](1_Dynamics/7_System_identification/Dynamic%20model%20parameter%20estimation.ipynb)
# * `numpy.random.random`: [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb)
# * `numpy.roots`: [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb), [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `numpy.sin`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb), [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb), [Regression](1_Dynamics/7_System_identification/Regression.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb)
# * `numpy.split`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `numpy.sqrt`: [Difference Functions](1_Dynamics/7_System_identification/Difference%20Functions.ipynb)
# * `numpy.tile`: [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb)
# * `numpy.zeros`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb)
# * `numpy.zeros_like`: [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb), [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb)
#
# # scipy
#
# * `scipy.integrate.odeint`: [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb)
# * `scipy.integrate.solve_ivp`: [Read input from file](1_Dynamics/2_Time_domain_simulation/Read%20input%20from%20file.ipynb), [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb), [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb), [Real time simulation](1_Dynamics/6_Multivariable_system_representation/Real%20time%20simulation.ipynb)
# * `scipy.integrate.trapz`: [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb)
# * `scipy.io.wavfile.read`: [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb)
# * `scipy.linalg.toeplitz`: [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb)
# * `scipy.optimize.curve_fit`: [Dynamic model parameter estimation](1_Dynamics/7_System_identification/Dynamic%20model%20parameter%20estimation.ipynb), [Regression](1_Dynamics/7_System_identification/Regression.ipynb)
# * `scipy.optimize.fsolve`: [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb), [Extra Python](0_Getting_Started/Extra%20Python.ipynb), [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb)
# * `scipy.optimize.least_squares`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `scipy.optimize.minimize`: [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb), [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb)
# * `scipy.signal.dlti`: [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb)
# * `scipy.signal.lsim`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb)
# * `scipy.signal.lti`: [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb), [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb), [Real time simulation](1_Dynamics/6_Multivariable_system_representation/Real%20time%20simulation.ipynb)
# * `scipy.signal.lti_conversion.ss2tf`: [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb)
# * `scipy.signal.lti_conversion.tf2ss`: [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb)
#
# # sympy
#
# * `sympy.And`: [Multivariable stability analysis](2_Control/7_Multivariable_control/Multivariable%20stability%20analysis.ipynb)
# * `sympy.Eq`: [Second order systems](1_Dynamics/4_First_and_second_order_system_dynamics/Second%20order%20systems.ipynb), [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb)
# * `sympy.Function`: [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb), [The blending system](1_Dynamics/1_Modelling/The%20blending%20system.ipynb)
# * `sympy.Heaviside`: [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb), [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb)
# * `sympy.Matrix`: [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb), [Multivariable stability analysis](2_Control/7_Multivariable_control/Multivariable%20stability%20analysis.ipynb), [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb), [Transfer function matrices](1_Dynamics/6_Multivariable_system_representation/Transfer%20function%20matrices.ipynb), [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb), [Multivariable closed loop transfer functions](2_Control/7_Multivariable_control/Multivariable%20closed%20loop%20transfer%20functions.ipynb), [Decoupling](2_Control/7_Multivariable_control/Decoupling.ipynb)
# * `sympy.N`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [Symbolic tools](1_Dynamics/1_Modelling/Symbolic%20tools.ipynb), [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb)
# * `sympy.Poly`: [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb)
# * `sympy.Rational`: [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [Numeric representation](1_Dynamics/2_Time_domain_simulation/Numeric%20representation.ipynb)
# * `sympy.Sum`: [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb)
# * `sympy.Symbol`: [Multivariable stability analysis](2_Control/7_Multivariable_control/Multivariable%20stability%20analysis.ipynb), [Sinusoidal response](1_Dynamics/4_First_and_second_order_system_dynamics/Sinusoidal%20response.ipynb), [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb), [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb), [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [Numeric representation](1_Dynamics/2_Time_domain_simulation/Numeric%20representation.ipynb), [Symbolic tools](1_Dynamics/1_Modelling/Symbolic%20tools.ipynb), [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb), [Transfer function matrices](1_Dynamics/6_Multivariable_system_representation/Transfer%20function%20matrices.ipynb), [Second order systems](1_Dynamics/4_First_and_second_order_system_dynamics/Second%20order%20systems.ipynb), [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb), [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb)
# * `sympy.cos`: [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb), [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb)
# * `sympy.denom`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb), [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb)
# * `sympy.diff`: [The blending system](1_Dynamics/1_Modelling/The%20blending%20system.ipynb)
# * `sympy.dsolve`: [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb), [The blending system](1_Dynamics/1_Modelling/The%20blending%20system.ipynb)
# * `sympy.exp`: [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb), [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb), [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb)
# * `sympy.expand`: [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb), [Symbolic tools](1_Dynamics/1_Modelling/Symbolic%20tools.ipynb)
# * `sympy.eye`: [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb)
# * `sympy.init_printing`: [Multivariable stability analysis](2_Control/7_Multivariable_control/Multivariable%20stability%20analysis.ipynb), [Sinusoidal response](1_Dynamics/4_First_and_second_order_system_dynamics/Sinusoidal%20response.ipynb), [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb), [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb), [Extra Python](0_Getting_Started/Extra%20Python.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [Numeric representation](1_Dynamics/2_Time_domain_simulation/Numeric%20representation.ipynb), [Symbolic tools](1_Dynamics/1_Modelling/Symbolic%20tools.ipynb), [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb), [The blending system](1_Dynamics/1_Modelling/The%20blending%20system.ipynb), [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb), [Transfer function matrices](1_Dynamics/6_Multivariable_system_representation/Transfer%20function%20matrices.ipynb), [Second order systems](1_Dynamics/4_First_and_second_order_system_dynamics/Second%20order%20systems.ipynb), [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Block diagram simplification](1_Dynamics/5_Complex_system_dynamics/Block%20diagram%20simplification.ipynb), [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Linearisation](1_Dynamics/3_Linear_systems/Linearisation.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [Multivariable closed loop transfer functions](2_Control/7_Multivariable_control/Multivariable%20closed%20loop%20transfer%20functions.ipynb), [Decoupling](2_Control/7_Multivariable_control/Decoupling.ipynb), [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb), [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb), [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb)
# * `sympy.integrate`: [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb), [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb)
# * `sympy.inverse_laplace_transform`: [Sinusoidal response](1_Dynamics/4_First_and_second_order_system_dynamics/Sinusoidal%20response.ipynb), [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb), [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb), [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [Second order systems](1_Dynamics/4_First_and_second_order_system_dynamics/Second%20order%20systems.ipynb)
# * `sympy.lambdify`: [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb)
# * `sympy.laplace_transform`: [Sinusoidal response](1_Dynamics/4_First_and_second_order_system_dynamics/Sinusoidal%20response.ipynb), [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb), [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Second order systems](1_Dynamics/4_First_and_second_order_system_dynamics/Second%20order%20systems.ipynb)
# * `sympy.limit`: [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb), [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb)
# * `sympy.log`: [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb)
# * `sympy.nsimplify`: [Second order systems](1_Dynamics/4_First_and_second_order_system_dynamics/Second%20order%20systems.ipynb), [Numeric representation](1_Dynamics/2_Time_domain_simulation/Numeric%20representation.ipynb)
# * `sympy.numer`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
# * `sympy.plot`: [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Sinusoidal response](1_Dynamics/4_First_and_second_order_system_dynamics/Sinusoidal%20response.ipynb), [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb), [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb), [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb), [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb), [Second order systems](1_Dynamics/4_First_and_second_order_system_dynamics/Second%20order%20systems.ipynb)
# * `sympy.plot_implicit`: [Multivariable stability analysis](2_Control/7_Multivariable_control/Multivariable%20stability%20analysis.ipynb)
# * `sympy.plotting.plot3d`: [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb)
# * `sympy.poly`: [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb), [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb), [Multivariable stability analysis](2_Control/7_Multivariable_control/Multivariable%20stability%20analysis.ipynb)
# * `sympy.re`: [Second order systems](1_Dynamics/4_First_and_second_order_system_dynamics/Second%20order%20systems.ipynb)
# * `sympy.roots`: [Second order systems](1_Dynamics/4_First_and_second_order_system_dynamics/Second%20order%20systems.ipynb), [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb)
# * `sympy.series`: [Linearisation](1_Dynamics/3_Linear_systems/Linearisation.ipynb), [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb)
# * `sympy.simplify`: [Numeric representation](1_Dynamics/2_Time_domain_simulation/Numeric%20representation.ipynb), [Multivariable closed loop transfer functions](2_Control/7_Multivariable_control/Multivariable%20closed%20loop%20transfer%20functions.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb), [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb), [Decoupling](2_Control/7_Multivariable_control/Decoupling.ipynb), [Transfer function matrices](1_Dynamics/6_Multivariable_system_representation/Transfer%20function%20matrices.ipynb)
# * `sympy.sin`: [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb), [Sinusoidal response](1_Dynamics/4_First_and_second_order_system_dynamics/Sinusoidal%20response.ipynb)
# * `sympy.solve`: [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Block diagram simplification](1_Dynamics/5_Complex_system_dynamics/Block%20diagram%20simplification.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb), [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb), [Symbolic tools](1_Dynamics/1_Modelling/Symbolic%20tools.ipynb), [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb), [Extra Python](0_Getting_Started/Extra%20Python.ipynb), [The blending system](1_Dynamics/1_Modelling/The%20blending%20system.ipynb), [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb), [Decoupling](2_Control/7_Multivariable_control/Decoupling.ipynb)
# * `sympy.sqrt`: [Numeric representation](1_Dynamics/2_Time_domain_simulation/Numeric%20representation.ipynb), [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb), [Sinusoidal response](1_Dynamics/4_First_and_second_order_system_dynamics/Sinusoidal%20response.ipynb)
# * `sympy.symbols`: [Multivariable stability analysis](2_Control/7_Multivariable_control/Multivariable%20stability%20analysis.ipynb), [Sinusoidal response](1_Dynamics/4_First_and_second_order_system_dynamics/Sinusoidal%20response.ipynb), [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb), [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb), [Extra Python](0_Getting_Started/Extra%20Python.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb), [The blending system](1_Dynamics/1_Modelling/The%20blending%20system.ipynb), [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb), [Second order systems](1_Dynamics/4_First_and_second_order_system_dynamics/Second%20order%20systems.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Block diagram simplification](1_Dynamics/5_Complex_system_dynamics/Block%20diagram%20simplification.ipynb), [Linearisation](1_Dynamics/3_Linear_systems/Linearisation.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Multivariable closed loop transfer functions](2_Control/7_Multivariable_control/Multivariable%20closed%20loop%20transfer%20functions.ipynb), [Decoupling](2_Control/7_Multivariable_control/Decoupling.ipynb), [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb), [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb)
# * `sympy.var`: [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb)
# * `sympy.zeros`: [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb), [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
#
# # mpmath
#
# * `mpmath.cplot`: [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb)
# * `mpmath.fourier`: [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb)
# * `mpmath.fourierval`: [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb)
# * `mpmath.plot`: [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb)
#
# # pandas
#
# * `pandas.DataFrame`: [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb)
# * `pandas.read_csv`: [Dealing with data](1_Dynamics/7_System_identification/Dealing%20with%20data.ipynb), [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb)
# * `pandas.read_excel`: [Read input from file](1_Dynamics/2_Time_domain_simulation/Read%20input%20from%20file.ipynb), [Regression](1_Dynamics/7_System_identification/Regression.ipynb)
#
# # plt
#
# * `plt.axhline`: [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb)
# * `plt.axis`: [Aliasing](1_Dynamics/9_Sampled_systems/Aliasing.ipynb), [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Eigenvalues and Eigenvectors](2_Control/7_Multivariable_control/Eigenvalues%20and%20Eigenvectors.ipynb), [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb)
# * `plt.axvline`: [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb)
# * `plt.figure`: [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb), [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `plt.gca`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `plt.legend`: [Dynamic model parameter estimation](1_Dynamics/7_System_identification/Dynamic%20model%20parameter%20estimation.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb), [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb), [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb), [Regression](1_Dynamics/7_System_identification/Regression.ipynb), [Dead time compensation](2_Control/5_Advanced_control_methods/Dead%20time%20compensation.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Difference Functions](1_Dynamics/7_System_identification/Difference%20Functions.ipynb)
# * `plt.loglog`: [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb)
# * `plt.pcolor`: [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb)
# * `plt.plot`: [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb), [Dead time compensation](2_Control/5_Advanced_control_methods/Dead%20time%20compensation.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Control valve design](2_Control/8_Control_Practice/Control%20valve%20design.ipynb), [Noise models](2_Control/6_Discrete_control_and_analysis/Noise%20models.ipynb), [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [Eigenvalues and Eigenvectors](2_Control/7_Multivariable_control/Eigenvalues%20and%20Eigenvectors.ipynb), [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb), [Dynamic model parameter estimation](1_Dynamics/7_System_identification/Dynamic%20model%20parameter%20estimation.ipynb), [PID controller step responses](2_Control/1_Conventional_feedback_control/PID%20controller%20step%20responses.ipynb), [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb), [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb), [Regression](1_Dynamics/7_System_identification/Regression.ipynb), [Difference Functions](1_Dynamics/7_System_identification/Difference%20Functions.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb), [Aliasing](1_Dynamics/9_Sampled_systems/Aliasing.ipynb), [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb), [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb), [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb), [Read input from file](1_Dynamics/2_Time_domain_simulation/Read%20input%20from%20file.ipynb), [Real time simulation](1_Dynamics/6_Multivariable_system_representation/Real%20time%20simulation.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb), [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb), [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb)
# * `plt.sca`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb), [Random response generator](1_Dynamics/5_Complex_system_dynamics/Random%20response%20generator.ipynb)
# * `plt.scatter`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb), [Dynamic model parameter estimation](1_Dynamics/7_System_identification/Dynamic%20model%20parameter%20estimation.ipynb), [Aliasing](1_Dynamics/9_Sampled_systems/Aliasing.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb), [Regression](1_Dynamics/7_System_identification/Regression.ipynb)
# * `plt.semilogx`: [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `plt.show`: [Eigenvalues and Eigenvectors](2_Control/7_Multivariable_control/Eigenvalues%20and%20Eigenvectors.ipynb), [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb), [Dynamic model parameter estimation](1_Dynamics/7_System_identification/Dynamic%20model%20parameter%20estimation.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb)
# * `plt.stem`: [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb)
# * `plt.subplot`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
# * `plt.subplot2grid`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `plt.subplots`: [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb), [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Random response generator](1_Dynamics/5_Complex_system_dynamics/Random%20response%20generator.ipynb)
# * `plt.text`: [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb)
# * `plt.tight_layout`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
# * `plt.title`: [Root locus diagrams](2_Control/2_Laplace_domain_analysis_of_control_systems/Root%20locus%20diagrams.ipynb), [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
# * `plt.xlabel`: [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb), [Control valve design](2_Control/8_Control_Practice/Control%20valve%20design.ipynb), [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb), [Difference Functions](1_Dynamics/7_System_identification/Difference%20Functions.ipynb)
# * `plt.xlim`: [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb)
# * `plt.ylabel`: [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb), [Control valve design](2_Control/8_Control_Practice/Control%20valve%20design.ipynb), [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb), [Difference Functions](1_Dynamics/7_System_identification/Difference%20Functions.ipynb)
# * `plt.ylim`: [Control valve design](2_Control/8_Control_Practice/Control%20valve%20design.ipynb), [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb)
#
# # control
#
# * `control.bode`: [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb)
# * `control.nyquist_plot`: [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb)
# * `control.pzmap`: [Random response generator](1_Dynamics/5_Complex_system_dynamics/Random%20response%20generator.ipynb)
# * `control.pzmap.pzmap`: [Root locus diagrams](2_Control/2_Laplace_domain_analysis_of_control_systems/Root%20locus%20diagrams.ipynb)
# * `control.rlocus`: [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb)
# * `control.root_locus`: [Root locus diagrams](2_Control/2_Laplace_domain_analysis_of_control_systems/Root%20locus%20diagrams.ipynb)
# * `control.ss`: [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb), [Transfer function matrices](1_Dynamics/6_Multivariable_system_representation/Transfer%20function%20matrices.ipynb)
# * `control.step_response`: [Dynamic model parameter estimation](1_Dynamics/7_System_identification/Dynamic%20model%20parameter%20estimation.ipynb), [PID controller step responses](2_Control/1_Conventional_feedback_control/PID%20controller%20step%20responses.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb), [Real time simulation](1_Dynamics/6_Multivariable_system_representation/Real%20time%20simulation.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [Random response generator](1_Dynamics/5_Complex_system_dynamics/Random%20response%20generator.ipynb)
# * `control.tf`: [Root locus diagrams](2_Control/2_Laplace_domain_analysis_of_control_systems/Root%20locus%20diagrams.ipynb), [Dynamic model parameter estimation](1_Dynamics/7_System_identification/Dynamic%20model%20parameter%20estimation.ipynb), [PID controller step responses](2_Control/1_Conventional_feedback_control/PID%20controller%20step%20responses.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb), [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb), [Real time simulation](1_Dynamics/6_Multivariable_system_representation/Real%20time%20simulation.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb), [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [Transfer function matrices](1_Dynamics/6_Multivariable_system_representation/Transfer%20function%20matrices.ipynb), [Random response generator](1_Dynamics/5_Complex_system_dynamics/Random%20response%20generator.ipynb)
#
# # Other
# * `A.solve`: [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb)
# * `Audio`: [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb)
# * `DataFrame`: [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb)
# * `F.apart`: [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb)
# * `Fin`: [Read input from file](1_Dynamics/2_Time_domain_simulation/Read%20input%20from%20file.ipynb), [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb)
# * `G`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `G.det`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
# * `G.inv`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
# * `G.multiply_elementwise`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
# * `G.step`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb)
# * `G.to_ss`: [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb), [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb)
# * `G2.to_ss`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb)
# * `G2ss.to_tf`: [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb)
# * `G_CL.pole`: [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb)
# * `G_CL.subs`: [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb)
# * `G_C_rational.simplify`: [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb)
# * `G_p.adjugate`: [Decoupling](2_Control/7_Multivariable_control/Decoupling.ipynb)
# * `G_p.applyfunc`: [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb)
# * `G_p.inverse_ADJ`: [Decoupling](2_Control/7_Multivariable_control/Decoupling.ipynb)
# * `Gc.change_input`: [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb)
# * `Gc.change_state`: [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb)
# * `Gdiscrete.step`: [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb)
# * `Geval`: [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb)
# * `Gnumeric`: [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb)
# * `Gp`: [Dead time compensation](2_Control/5_Advanced_control_methods/Dead%20time%20compensation.ipynb)
# * `Gss.A.dot`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb)
# * `Gss.B.dot`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb)
# * `Gss.C.dot`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb)
# * `Gss.D.dot`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb)
# * `Gtf.pole`: [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb)
# * `Gz.cancel`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb)
# * `Gz.expand`: [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb)
# * `Gz.subs`: [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb)
# * `K.multiply_elementwise`: [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb)
# * `L`: [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb), [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb)
# * `PIController`: [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb)
# * `R`: [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb)
# * `S`: [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb)
# * `T.subs`: [Decoupling](2_Control/7_Multivariable_control/Decoupling.ipynb)
# * `Tends.append`: [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb)
# * `X.append`: [Difference Functions](1_Dynamics/7_System_identification/Difference%20Functions.ipynb), [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb)
# * `Y.append`: [Difference Functions](1_Dynamics/7_System_identification/Difference%20Functions.ipynb), [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb)
# * `annotated_bode`: [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `approximation.subs`: [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb)
# * `ax.axis`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `ax.set_aspect`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `ax.xaxis.tick_bottom`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `ax.yaxis.tick_left`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `axT.plot`: [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb)
# * `axT.set_ylabel`: [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb)
# * `ax_complex.axhline`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `ax_complex.axis`: [Random response generator](1_Dynamics/5_Complex_system_dynamics/Random%20response%20generator.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `ax_complex.axvline`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `ax_complex.grid`: [Random response generator](1_Dynamics/5_Complex_system_dynamics/Random%20response%20generator.ipynb)
# * `ax_complex.plot`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `ax_complex.scatter`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `ax_complex.set_title`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb)
# * `ax_e.plot`: [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb)
# * `ax_e.set_ylabel`: [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb)
# * `ax_gain.axhline`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `ax_gain.axvline`: [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `ax_gain.loglog`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `ax_gain.set_ylabel`: [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `ax_gain.set_ylim`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `ax_impulse.plot`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb)
# * `ax_impulse.set_title`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb)
# * `ax_impulse.set_ylim`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb)
# * `ax_mag.loglog`: [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb)
# * `ax_phase.axhline`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `ax_phase.axvline`: [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `ax_phase.semilogx`: [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb), [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `ax_phase.set_ylabel`: [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `ax_phase.set_ylim`: [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `ax_step.axhline`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb)
# * `ax_step.plot`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb)
# * `ax_step.set_title`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb)
# * `ax_step.set_ylim`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb)
# * `ax_step.text`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb)
# * `ax_time.axhline`: [Random response generator](1_Dynamics/5_Complex_system_dynamics/Random%20response%20generator.ipynb)
# * `ax_time.plot`: [Random response generator](1_Dynamics/5_Complex_system_dynamics/Random%20response%20generator.ipynb)
# * `ax_u.plot`: [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb)
# * `ax_y.axhline`: [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb)
# * `ax_y.plot`: [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb)
# * `ax_y.set_ylabel`: [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb)
# * `axcA.legend`: [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb)
# * `axcA.plot`: [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb)
# * `axcA.set_ylabel`: [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb)
# * `bigsymbolicA.solve`: [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb)
# * `blocksim.Deadtime`: [Dead time compensation](2_Control/5_Advanced_control_methods/Dead%20time%20compensation.ipynb)
# * `blocksim.Diagram`: [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb), [Dead time compensation](2_Control/5_Advanced_control_methods/Dead%20time%20compensation.ipynb)
# * `blocksim.LTI`: [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb), [Dead time compensation](2_Control/5_Advanced_control_methods/Dead%20time%20compensation.ipynb)
# * `blocksim.PI`: [Dead time compensation](2_Control/5_Advanced_control_methods/Dead%20time%20compensation.ipynb)
# * `bode`: [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb)
# * `ce.expand`: [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb)
# * `chareq.as_numer_denom`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
# * `chareq.factor`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
# * `closedloop`: [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb)
# * `controller`: [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb)
# * `cos`: [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb)
# * `cplot`: [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb)
# * `curve`: [Control valve design](2_Control/8_Control_Practice/Control%20valve%20design.ipynb)
# * `data.plot`: [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb)
# * `data.sort_index`: [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb)
# * `decimal.Decimal`: [Numeric representation](1_Dynamics/2_Time_domain_simulation/Numeric%20representation.ipynb)
# * `denom.subs`: [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb)
# * `dhdt`: [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb)
# * `diagram.simulate`: [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb), [Dead time compensation](2_Control/5_Advanced_control_methods/Dead%20time%20compensation.ipynb)
# * `diagrams.items`: [Dead time compensation](2_Control/5_Advanced_control_methods/Dead%20time%20compensation.ipynb)
# * `discretecoeffs`: [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb)
# * `enumerate`: [Multivariable stability analysis](2_Control/7_Multivariable_control/Multivariable%20stability%20analysis.ipynb), [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb)
# * `eq.coeffs`: [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb)
# * `error.__name__.upper`: [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb)
# * `exp`: [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb)
# * `expr.subs`: [Linearisation](1_Dynamics/3_Linear_systems/Linearisation.ipynb)
# * `expz`: [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb)
# * `extend`: [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb)
# * `f`: [Real time simulation](1_Dynamics/6_Multivariable_system_representation/Real%20time%20simulation.ipynb), [Aliasing](1_Dynamics/9_Sampled_systems/Aliasing.ipynb), [Symbolic tools](1_Dynamics/1_Modelling/Symbolic%20tools.ipynb)
# * `f.subs`: [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb)
# * `f.write`: [Dealing with data](1_Dynamics/7_System_identification/Dealing%20with%20data.ipynb)
# * `f2numeric`: [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb)
# * `feedback`: [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb)
# * `filtersignal`: [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb)
# * `fin`: [Real time simulation](1_Dynamics/6_Multivariable_system_representation/Real%20time%20simulation.ipynb)
# * `firstorder`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb)
# * `fit_and_plot`: [Regression](1_Dynamics/7_System_identification/Regression.ipynb)
# * `fiterror`: [Regression](1_Dynamics/7_System_identification/Regression.ipynb)
# * `fixaxis`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `flat.append`: [Symbolic tools](1_Dynamics/1_Modelling/Symbolic%20tools.ipynb)
# * `float`: [Real time simulation](1_Dynamics/6_Multivariable_system_representation/Real%20time%20simulation.ipynb), [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb), [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb)
# * `fopdtitae.parameters`: [ITAE parameters for FOPDT system](2_Control/3_PID_controller_design_tuning_and_troubleshooting/ITAE%20parameters%20for%20FOPDT%20system.ipynb), [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb)
# * `frequencyplot`: [Sinusoidal response](1_Dynamics/4_First_and_second_order_system_dynamics/Sinusoidal%20response.ipynb)
# * `func`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
# * `fz.subs`: [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb)
# * `ga.subs`: [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb)
# * `geval`: [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb)
# * `h`: [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb)
# * `int`: [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb)
# * `interact`: [Root locus diagrams](2_Control/2_Laplace_domain_analysis_of_control_systems/Root%20locus%20diagrams.ipynb), [ITAE parameters for FOPDT system](2_Control/3_PID_controller_design_tuning_and_troubleshooting/ITAE%20parameters%20for%20FOPDT%20system.ipynb), [Aliasing](1_Dynamics/9_Sampled_systems/Aliasing.ipynb), [Dynamic model parameter estimation](1_Dynamics/7_System_identification/Dynamic%20model%20parameter%20estimation.ipynb), [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Sinusoidal response](1_Dynamics/4_First_and_second_order_system_dynamics/Sinusoidal%20response.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb), [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb), [Random response generator](1_Dynamics/5_Complex_system_dynamics/Random%20response%20generator.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Control valve design](2_Control/8_Control_Practice/Control%20valve%20design.ipynb), [Eigenvalues and Eigenvectors](2_Control/7_Multivariable_control/Eigenvalues%20and%20Eigenvectors.ipynb), [Second order systems](1_Dynamics/4_First_and_second_order_system_dynamics/Second%20order%20systems.ipynb)
# * `intsys`: [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb)
# * `invL`: [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb), [Second order systems](1_Dynamics/4_First_and_second_order_system_dynamics/Second%20order%20systems.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb)
# * `itae`: [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb)
# * `keras.models.Sequential`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `l.append`: [Extra Python](0_Getting_Started/Extra%20Python.ipynb)
# * `len`: [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb), [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Symbolic tools](1_Dynamics/1_Modelling/Symbolic%20tools.ipynb), [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb), [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb), [Extra Python](0_Getting_Started/Extra%20Python.ipynb)
# * `limit`: [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb)
# * `linearise`: [Linearisation](1_Dynamics/3_Linear_systems/Linearisation.ipynb)
# * `lineq.subs`: [Linearisation](1_Dynamics/3_Linear_systems/Linearisation.ipynb)
# * `list`: [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [Extra Python](0_Getting_Started/Extra%20Python.ipynb), [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb), [Linearisation](1_Dynamics/3_Linear_systems/Linearisation.ipynb)
# * `max`: [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb)
# * `model.add`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `model.compile`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `model.fit`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `multiple_equations`: [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb)
# * `my_solve_ivp`: [Real time simulation](1_Dynamics/6_Multivariable_system_representation/Real%20time%20simulation.ipynb)
# * `net.fit`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `network_output`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `numer.all_coeffs`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
# * `nyquist`: [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb)
# * `nyquistplot`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `objective`: [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb)
# * `open`: [Dealing with data](1_Dynamics/7_System_identification/Dealing%20with%20data.ipynb)
# * `p.all_coeffs`: [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb), [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
# * `p.append`: [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb)
# * `p.extend`: [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb)
# * `p.show`: [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb), [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb)
# * `p1.extend`: [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb)
# * `p1.show`: [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb)
# * `pack`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `pade`: [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb)
# * `plot_approx`: [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb)
# * `plot_step_response`: [PID controller step responses](2_Control/1_Conventional_feedback_control/PID%20controller%20step%20responses.ipynb)
# * `plotcomplex`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `plotdiscrete`: [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb)
# * `plotfit`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `plotoutput`: [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb)
# * `plotpz`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `plotsituation`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `plotstep`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb)
# * `plotvector`: [Eigenvalues and Eigenvectors](2_Control/7_Multivariable_control/Eigenvalues%20and%20Eigenvectors.ipynb)
# * `polynomial`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `polynomial.diff`: [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb)
# * `polynomial.expand`: [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb)
# * `polynomial.integrate`: [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb)
# * `positive`: [Control valve design](2_Control/8_Control_Practice/Control%20valve%20design.ipynb)
# * `predict`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `prediction`: [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb)
# * `print`: [ITAE parameters for FOPDT system](2_Control/3_PID_controller_design_tuning_and_troubleshooting/ITAE%20parameters%20for%20FOPDT%20system.ipynb), [Multivariable stability analysis](2_Control/7_Multivariable_control/Multivariable%20stability%20analysis.ipynb), [Real time simulation](1_Dynamics/6_Multivariable_system_representation/Real%20time%20simulation.ipynb), [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb), [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb), [Extra Python](0_Getting_Started/Extra%20Python.ipynb), [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb), [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb)
# * `qpoly.all_coeffs`: [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb)
# * `qsubs`: [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb)
# * `range`: [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Numeric representation](1_Dynamics/2_Time_domain_simulation/Numeric%20representation.ipynb), [Real time simulation](1_Dynamics/6_Multivariable_system_representation/Real%20time%20simulation.ipynb), [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb), [Extra Python](0_Getting_Started/Extra%20Python.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb), [Difference Functions](1_Dynamics/7_System_identification/Difference%20Functions.ipynb)
# * `regplot`: [Regression](1_Dynamics/7_System_identification/Regression.ipynb)
# * `response`: [Sinusoidal response](1_Dynamics/4_First_and_second_order_system_dynamics/Sinusoidal%20response.ipynb)
# * `result.append`: [Noise models](2_Control/6_Discrete_control_and_analysis/Noise%20models.ipynb), [Real time simulation](1_Dynamics/6_Multivariable_system_representation/Real%20time%20simulation.ipynb), [Extra Python](0_Getting_Started/Extra%20Python.ipynb)
# * `routh`: [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb), [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Multivariable stability analysis](2_Control/7_Multivariable_control/Multivariable%20stability%20analysis.ipynb)
# * `sampledvalues`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb)
# * `self.reset`: [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb)
# * `sigmoid`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `simulate`: [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb), [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb)
# * `sin`: [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb)
# * `sklearn.neural_network.MLPRegressor`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `smooth_1st`: [Difference Functions](1_Dynamics/7_System_identification/Difference%20Functions.ipynb)
# * `song.sum`: [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb)
# * `ss`: [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb)
# * `step`: [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb)
# * `sum`: [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Numeric representation](1_Dynamics/2_Time_domain_simulation/Numeric%20representation.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb), [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb), [Regression](1_Dynamics/7_System_identification/Regression.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb)
# * `sys.path.append`: [ITAE parameters for FOPDT system](2_Control/3_PID_controller_design_tuning_and_troubleshooting/ITAE%20parameters%20for%20FOPDT%20system.ipynb), [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb), [Dead time compensation](2_Control/5_Advanced_control_methods/Dead%20time%20compensation.ipynb)
# * `tablefunction`: [ITAE parameters for FOPDT system](2_Control/3_PID_controller_design_tuning_and_troubleshooting/ITAE%20parameters%20for%20FOPDT%20system.ipynb)
# * `taylor`: [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb)
# * `temp.removeO`: [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb)
# * `time.sleep`: [Real time simulation](1_Dynamics/6_Multivariable_system_representation/Real%20time%20simulation.ipynb)
# * `time.time`: [Real time simulation](1_Dynamics/6_Multivariable_system_representation/Real%20time%20simulation.ipynb)
# * `type`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb), [Extra Python](0_Getting_Started/Extra%20Python.ipynb), [Symbolic tools](1_Dynamics/1_Modelling/Symbolic%20tools.ipynb), [Numeric representation](1_Dynamics/2_Time_domain_simulation/Numeric%20representation.ipynb)
# * `u`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb)
# * `u_continuous.append`: [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb)
# * `u_discrete.append`: [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb)
# * `uaxis.plot`: [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb)
# * `uaxis.set_ylabel`: [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb)
# * `unitstep.doit`: [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb)
# * `unpack`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `unsolvable_numeric`: [Equation solving tools](1_Dynamics/1_Modelling/Equation%20solving%20tools.ipynb)
# * `xs.append`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb)
# * `y_continuous.append`: [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb)
# * `y_discrete.append`: [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb)
# * `y_func`: [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb)
# * `yaxis.legend`: [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb)
# * `yaxis.plot`: [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb)
# * `yaxis.set_ylabel`: [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb)
# * `ys.append`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb)
# * `ys_statespace.append`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb)
# * `yz.subs`: [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb)
# * `zeroeq.as_numer_denom`: [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb)
# * `zip`: [ITAE parameters for FOPDT system](2_Control/3_PID_controller_design_tuning_and_troubleshooting/ITAE%20parameters%20for%20FOPDT%20system.ipynb), [Extra Python](0_Getting_Started/Extra%20Python.ipynb), [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb)
