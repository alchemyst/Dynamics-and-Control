# %% [markdown]
# This file contains all the function calls in all the notebooks. It is currently updated manually, so it might be a little out of date.

# %% [markdown]
# # numpy
#
# * `numpy.abs`: [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb), [Control game](2_Control/1_Conventional_feedback_control/Control%20game.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb)
# * `numpy.angle`: [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [Frequency domain](tclab/Frequency%20domain.ipynb)
# * `numpy.arange`: [Regression](1_Dynamics/7_System_identification/Regression.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [Aliasing](1_Dynamics/9_Sampled_systems/Aliasing.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [RQ Online controller tuning](2_Control/3_PID_controller_design_tuning_and_troubleshooting/RQ%20Online%20controller%20tuning.ipynb), [Simple discrete controller simulation](2_Control/6_Discrete_control_and_analysis/Simple%20discrete%20controller%20simulation.ipynb), [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb), [Blocksim](Simulation/Blocksim.ipynb), [Continuous PID on TCLab](tclab/Continuous%20PID%20on%20TCLab.ipynb), [Difference Functions](under_construction/Difference%20Functions.ipynb)
# * `numpy.array`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb), [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb), [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb), [Timing study](Simulation/Timing%20study.ipynb), [FOPDT fit](tclab/FOPDT%20fit.ipynb), [Frequency domain](tclab/Frequency%20domain.ipynb), [TCLab step test](tclab/TCLab%20step%20test.ipynb), [Difference Functions](under_construction/Difference%20Functions.ipynb)
# * `numpy.asmatrix`: [Regression](1_Dynamics/7_System_identification/Regression.ipynb), [Eigenvalues and Eigenvectors](2_Control/7_Multivariable_control/Eigenvalues%20and%20Eigenvectors.ipynb)
# * `numpy.atleast_2d`: [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb), [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb), [Fitting example](under_construction/Fitting%20example.ipynb)
# * `numpy.bmat`: [Regression](1_Dynamics/7_System_identification/Regression.ipynb)
# * `numpy.clip`: [Blocksim](Simulation/Blocksim.ipynb)
# * `numpy.concatenate`: [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb), [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb), [PID controller step responses](2_Control/1_Conventional_feedback_control/PID%20controller%20step%20responses.ipynb), [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb), [Frequency domain](tclab/Frequency%20domain.ipynb)
# * `numpy.convolve`: [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb), [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb), [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb), [RQ Online controller tuning](2_Control/3_PID_controller_design_tuning_and_troubleshooting/RQ%20Online%20controller%20tuning.ipynb)
# * `numpy.cos`: [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb)
# * `numpy.cumsum`: [Noise models](2_Control/6_Discrete_control_and_analysis/Noise%20models.ipynb)
# * `numpy.empty`: [Timing study](Simulation/Timing%20study.ipynb)
# * `numpy.exp`: [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb), [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb), [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb), [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb), [RQ Freq basics](2_Control/4_Frequency_domain_analysis_of_control_systems/RQ%20Freq%20basics.ipynb), [Simple discrete controller simulation](2_Control/6_Discrete_control_and_analysis/Simple%20discrete%20controller%20simulation.ipynb), [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb), [Frequency domain](tclab/Frequency%20domain.ipynb), [Difference Functions](under_construction/Difference%20Functions.ipynb)
# * `numpy.fft.rfft`: [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb), [Frequency domain](tclab/Frequency%20domain.ipynb)
# * `numpy.fft.rfftfreq`: [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb), [Frequency domain](tclab/Frequency%20domain.ipynb)
# * `numpy.hstack`: [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb), [Fitting example](under_construction/Fitting%20example.ipynb)
# * `numpy.interp`: [Read input from file](1_Dynamics/2_Time_domain_simulation/Read%20input%20from%20file.ipynb), [Closed loop controlled responses](2_Control/1_Conventional_feedback_control/Closed%20loop%20controlled%20responses.ipynb), [Timing study](Simulation/Timing%20study.ipynb), [Difference Functions](under_construction/Difference%20Functions.ipynb)
# * `numpy.linalg.det`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
# * `numpy.linalg.eig`: [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb), [Eigenvalues and Eigenvectors](2_Control/7_Multivariable_control/Eigenvalues%20and%20Eigenvectors.ipynb)
# * `numpy.linalg.inv`: [Regression](1_Dynamics/7_System_identification/Regression.ipynb), [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb)
# * `numpy.linalg.lstsq`: [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb), [Regression](1_Dynamics/7_System_identification/Regression.ipynb), [Difference Functions](under_construction/Difference%20Functions.ipynb), [Fitting example](under_construction/Fitting%20example.ipynb)
# * `numpy.linalg.norm`: [Eigenvalues and Eigenvectors](2_Control/7_Multivariable_control/Eigenvalues%20and%20Eigenvectors.ipynb)
# * `numpy.linalg.solve`: [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb)
# * `numpy.linalg.svd`: [Eigenvalues and Eigenvectors](2_Control/7_Multivariable_control/Eigenvalues%20and%20Eigenvectors.ipynb)
# * `numpy.linspace`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb), [Fed batch bioreactor](1_Dynamics/2_Time_domain_simulation/Fed%20batch%20bioreactor.ipynb), [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb), [Read input from file](1_Dynamics/2_Time_domain_simulation/Read%20input%20from%20file.ipynb), [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb), [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb), [Regression](1_Dynamics/7_System_identification/Regression.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb), [Aliasing](1_Dynamics/9_Sampled_systems/Aliasing.ipynb), [Filtering](1_Dynamics/9_Sampled_systems/Filtering.ipynb), [The z domain and continuous systems](1_Dynamics/9_Sampled_systems/The%20z%20domain%20and%20continuous%20systems.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [Closed loop controlled responses](2_Control/1_Conventional_feedback_control/Closed%20loop%20controlled%20responses.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [PID controller step responses](2_Control/1_Conventional_feedback_control/PID%20controller%20step%20responses.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb), [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb), [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb), [RQ Freq basics](2_Control/4_Frequency_domain_analysis_of_control_systems/RQ%20Freq%20basics.ipynb), [Dead time compensation](2_Control/5_Advanced_control_methods/Dead%20time%20compensation.ipynb), [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb), [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb), [Control valve design](2_Control/8_Control_Practice/Control%20valve%20design.ipynb), [Hybrid system simulation](Simulation/Hybrid%20system%20simulation.ipynb), [Object-Oriented simulation - Discrete](Simulation/Object-Oriented%20simulation%20-%20Discrete.ipynb), [Object-Oriented simulation](Simulation/Object-Oriented%20simulation.ipynb), [Timing study](Simulation/Timing%20study.ipynb), [Difference Functions](under_construction/Difference%20Functions.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb), [Real time simulation](under_construction/Real%20time%20simulation.ipynb)
# * `numpy.log`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
# * `numpy.logspace`: [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb), [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb), [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb), [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb), [RQ Freq basics](2_Control/4_Frequency_domain_analysis_of_control_systems/RQ%20Freq%20basics.ipynb), [Frequency domain](tclab/Frequency%20domain.ipynb)
# * `numpy.matrix`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb), [Eigenvalues and Eigenvectors](2_Control/7_Multivariable_control/Eigenvalues%20and%20Eigenvectors.ipynb), [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb)
# * `numpy.max`: [Frequency domain](tclab/Frequency%20domain.ipynb)
# * `numpy.maximum`: [FOPDT fit](tclab/FOPDT%20fit.ipynb), [TCLab step test](tclab/TCLab%20step%20test.ipynb)
# * `numpy.meshgrid`: [Multivariable stability analysis](2_Control/7_Multivariable_control/Multivariable%20stability%20analysis.ipynb)
# * `numpy.minimum`: [Control game](2_Control/1_Conventional_feedback_control/Control%20game.ipynb)
# * `numpy.ones`: [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb), [Timing study](Simulation/Timing%20study.ipynb)
# * `numpy.ones_like`: [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [Difference Functions](under_construction/Difference%20Functions.ipynb)
# * `numpy.polyfit`: [Regression](1_Dynamics/7_System_identification/Regression.ipynb)
# * `numpy.polyval`: [Regression](1_Dynamics/7_System_identification/Regression.ipynb), [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb)
# * `numpy.rad2deg`: [Eigenvalues and Eigenvectors](2_Control/7_Multivariable_control/Eigenvalues%20and%20Eigenvectors.ipynb)
# * `numpy.random.normal`: [Difference Functions](under_construction/Difference%20Functions.ipynb)
# * `numpy.random.rand`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `numpy.random.randn`: [Dynamic model parameter estimation](1_Dynamics/7_System_identification/Dynamic%20model%20parameter%20estimation.ipynb), [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb), [Filtering](1_Dynamics/9_Sampled_systems/Filtering.ipynb), [Noise models](2_Control/6_Discrete_control_and_analysis/Noise%20models.ipynb)
# * `numpy.random.random`: [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb)
# * `numpy.random.uniform`: [Frequency domain](tclab/Frequency%20domain.ipynb)
# * `numpy.roots`: [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb), [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb)
# * `numpy.sin`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb), [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb), [Regression](1_Dynamics/7_System_identification/Regression.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb), [Frequency domain](tclab/Frequency%20domain.ipynb)
# * `numpy.split`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `numpy.sqrt`: [Hybrid system simulation](Simulation/Hybrid%20system%20simulation.ipynb), [Object-Oriented simulation - Discrete](Simulation/Object-Oriented%20simulation%20-%20Discrete.ipynb), [Object-Oriented simulation](Simulation/Object-Oriented%20simulation.ipynb), [Difference Functions](under_construction/Difference%20Functions.ipynb)
# * `numpy.tile`: [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb)
# * `numpy.trapz`: [RQ tuning relations](2_Control/3_PID_controller_design_tuning_and_troubleshooting/RQ%20tuning%20relations.ipynb)
# * `numpy.zeros`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb), [Hybrid system simulation](Simulation/Hybrid%20system%20simulation.ipynb)
# * `numpy.zeros_like`: [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb)
#
# # scipy
#
# * `scipy.integrate.odeint`: [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb)
# * `scipy.integrate.solve_ivp`: [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb), [Fed batch bioreactor](1_Dynamics/2_Time_domain_simulation/Fed%20batch%20bioreactor.ipynb), [Mixing system](1_Dynamics/2_Time_domain_simulation/Mixing%20system.ipynb), [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb), [Read input from file](1_Dynamics/2_Time_domain_simulation/Read%20input%20from%20file.ipynb), [Solve IVP](2_Control/1_Conventional_feedback_control/Solve%20IVP.ipynb), [Real time simulation](under_construction/Real%20time%20simulation.ipynb)
# * `scipy.integrate.trapz`: [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb)
# * `scipy.io.wavfile.read`: [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb)
# * `scipy.linalg.toeplitz`: [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb), [Fitting example](under_construction/Fitting%20example.ipynb)
# * `scipy.optimize.curve_fit`: [Dynamic model parameter estimation](1_Dynamics/7_System_identification/Dynamic%20model%20parameter%20estimation.ipynb), [Regression](1_Dynamics/7_System_identification/Regression.ipynb)
# * `scipy.optimize.fsolve`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Extra Python](0_Getting_Started/Extra%20Python.ipynb), [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb), [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb), [RQ Freq basics](2_Control/4_Frequency_domain_analysis_of_control_systems/RQ%20Freq%20basics.ipynb)
# * `scipy.optimize.least_squares`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `scipy.optimize.minimize`: [Control game](2_Control/1_Conventional_feedback_control/Control%20game.ipynb), [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb)
# * `scipy.signal.dlti`: [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb)
# * `scipy.signal.lsim`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb), [Control game](2_Control/1_Conventional_feedback_control/Control%20game.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb)
# * `scipy.signal.lti`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb), [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb), [Control game](2_Control/1_Conventional_feedback_control/Control%20game.ipynb), [RQ tuning relations](2_Control/3_PID_controller_design_tuning_and_troubleshooting/RQ%20tuning%20relations.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb), [Object-Oriented simulation](Simulation/Object-Oriented%20simulation.ipynb), [Real time simulation](under_construction/Real%20time%20simulation.ipynb)
# * `scipy.signal.lti_conversion.ss2tf`: [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb)
# * `scipy.signal.lti_conversion.tf2ss`: [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb)
# * `scipy.signal.step`: [RQ tuning relations](2_Control/3_PID_controller_design_tuning_and_troubleshooting/RQ%20tuning%20relations.ipynb)
#
# # sympy
#
# * `sympy.And`: [Multivariable stability analysis](2_Control/7_Multivariable_control/Multivariable%20stability%20analysis.ipynb)
# * `sympy.Eq`: [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb), [Second order systems](1_Dynamics/4_First_and_second_order_system_dynamics/Second%20order%20systems.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `sympy.Function`: [The blending system](1_Dynamics/1_Modelling/The%20blending%20system.ipynb), [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb)
# * `sympy.Heaviside`: [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb)
# * `sympy.Matrix`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb), [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb), [Transfer function matrices](1_Dynamics/6_Multivariable_system_representation/Transfer%20function%20matrices.ipynb), [Decoupling](2_Control/7_Multivariable_control/Decoupling.ipynb), [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb), [Multivariable closed loop transfer functions](2_Control/7_Multivariable_control/Multivariable%20closed%20loop%20transfer%20functions.ipynb), [Multivariable stability analysis](2_Control/7_Multivariable_control/Multivariable%20stability%20analysis.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `sympy.N`: [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [RQ tuning relations](2_Control/3_PID_controller_design_tuning_and_troubleshooting/RQ%20tuning%20relations.ipynb), [Symbolic tools](under_construction/Symbolic%20tools.ipynb)
# * `sympy.Poly`: [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb)
# * `sympy.Rational`: [Numeric representation](1_Dynamics/2_Time_domain_simulation/Numeric%20representation.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `sympy.Sum`: [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb)
# * `sympy.Symbol`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb), [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb), [Numeric representation](1_Dynamics/2_Time_domain_simulation/Numeric%20representation.ipynb), [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb), [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Second order systems](1_Dynamics/4_First_and_second_order_system_dynamics/Second%20order%20systems.ipynb), [Sinusoidal response](1_Dynamics/4_First_and_second_order_system_dynamics/Sinusoidal%20response.ipynb), [Transfer function matrices](1_Dynamics/6_Multivariable_system_representation/Transfer%20function%20matrices.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [The z domain and continuous systems](1_Dynamics/9_Sampled_systems/The%20z%20domain%20and%20continuous%20systems.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb), [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb), [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb), [Multivariable stability analysis](2_Control/7_Multivariable_control/Multivariable%20stability%20analysis.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb), [Numbers vs symbols](under_construction/Numbers%20vs%20symbols.ipynb), [Symbolic tools](under_construction/Symbolic%20tools.ipynb)
# * `sympy.cos`: [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb), [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb)
# * `sympy.denom`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb), [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb), [Example 10.11](2_Control/4_Frequency_domain_analysis_of_control_systems/Example%2010.11.ipynb)
# * `sympy.diff`: [The blending system](1_Dynamics/1_Modelling/The%20blending%20system.ipynb)
# * `sympy.dsolve`: [The blending system](1_Dynamics/1_Modelling/The%20blending%20system.ipynb), [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb)
# * `sympy.exp`: [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [The z domain and continuous systems](1_Dynamics/9_Sampled_systems/The%20z%20domain%20and%20continuous%20systems.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb), [Example 10.11](2_Control/4_Frequency_domain_analysis_of_control_systems/Example%2010.11.ipynb), [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb), [Triangular response](under_construction/Triangular%20response.ipynb)
# * `sympy.expand`: [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb), [Symbolic tools](under_construction/Symbolic%20tools.ipynb)
# * `sympy.im`: [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `sympy.init_printing`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Extra Python](0_Getting_Started/Extra%20Python.ipynb), [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb), [Draining cup](1_Dynamics/1_Modelling/Draining%20cup.ipynb), [The blending system](1_Dynamics/1_Modelling/The%20blending%20system.ipynb), [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb), [Numeric representation](1_Dynamics/2_Time_domain_simulation/Numeric%20representation.ipynb), [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb), [Linearisation](1_Dynamics/3_Linear_systems/Linearisation.ipynb), [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Second order systems](1_Dynamics/4_First_and_second_order_system_dynamics/Second%20order%20systems.ipynb), [Sinusoidal response](1_Dynamics/4_First_and_second_order_system_dynamics/Sinusoidal%20response.ipynb), [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Block diagram simplification](1_Dynamics/5_Complex_system_dynamics/Block%20diagram%20simplification.ipynb), [Transfer function matrices](1_Dynamics/6_Multivariable_system_representation/Transfer%20function%20matrices.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [The z domain and continuous systems](1_Dynamics/9_Sampled_systems/The%20z%20domain%20and%20continuous%20systems.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb), [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb), [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb), [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Decoupling](2_Control/7_Multivariable_control/Decoupling.ipynb), [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb), [Multivariable closed loop transfer functions](2_Control/7_Multivariable_control/Multivariable%20closed%20loop%20transfer%20functions.ipynb), [Multivariable stability analysis](2_Control/7_Multivariable_control/Multivariable%20stability%20analysis.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb), [Numbers vs symbols](under_construction/Numbers%20vs%20symbols.ipynb), [Symbolic tools](under_construction/Symbolic%20tools.ipynb), [Triangular response](under_construction/Triangular%20response.ipynb)
# * `sympy.integrate`: [Draining cup](1_Dynamics/1_Modelling/Draining%20cup.ipynb), [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [RQ tuning relations](2_Control/3_PID_controller_design_tuning_and_troubleshooting/RQ%20tuning%20relations.ipynb)
# * `sympy.inverse_laplace_transform`: [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Second order systems](1_Dynamics/4_First_and_second_order_system_dynamics/Second%20order%20systems.ipynb), [Sinusoidal response](1_Dynamics/4_First_and_second_order_system_dynamics/Sinusoidal%20response.ipynb), [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [The z domain and continuous systems](1_Dynamics/9_Sampled_systems/The%20z%20domain%20and%20continuous%20systems.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb), [RQ tuning relations](2_Control/3_PID_controller_design_tuning_and_troubleshooting/RQ%20tuning%20relations.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `sympy.lambdify`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb), [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Multivariable stability analysis](2_Control/7_Multivariable_control/Multivariable%20stability%20analysis.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `sympy.laplace_transform`: [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Second order systems](1_Dynamics/4_First_and_second_order_system_dynamics/Second%20order%20systems.ipynb), [Sinusoidal response](1_Dynamics/4_First_and_second_order_system_dynamics/Sinusoidal%20response.ipynb), [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `sympy.limit`: [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb), [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb)
# * `sympy.log`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb)
# * `sympy.nsimplify`: [Numeric representation](1_Dynamics/2_Time_domain_simulation/Numeric%20representation.ipynb), [Second order systems](1_Dynamics/4_First_and_second_order_system_dynamics/Second%20order%20systems.ipynb)
# * `sympy.nsolve`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb)
# * `sympy.numer`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
# * `sympy.plot`: [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb), [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb), [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb), [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb), [Second order systems](1_Dynamics/4_First_and_second_order_system_dynamics/Second%20order%20systems.ipynb), [Sinusoidal response](1_Dynamics/4_First_and_second_order_system_dynamics/Sinusoidal%20response.ipynb), [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb), [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb), [RQ tuning relations](2_Control/3_PID_controller_design_tuning_and_troubleshooting/RQ%20tuning%20relations.ipynb), [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Triangular response](under_construction/Triangular%20response.ipynb)
# * `sympy.plot_implicit`: [Multivariable stability analysis](2_Control/7_Multivariable_control/Multivariable%20stability%20analysis.ipynb)
# * `sympy.plotting.plot3d`: [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb)
# * `sympy.poly`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb), [Example 10.11](2_Control/4_Frequency_domain_analysis_of_control_systems/Example%2010.11.ipynb), [Multivariable stability analysis](2_Control/7_Multivariable_control/Multivariable%20stability%20analysis.ipynb)
# * `sympy.re`: [Second order systems](1_Dynamics/4_First_and_second_order_system_dynamics/Second%20order%20systems.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `sympy.roots`: [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb), [Second order systems](1_Dynamics/4_First_and_second_order_system_dynamics/Second%20order%20systems.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `sympy.series`: [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb), [Linearisation](1_Dynamics/3_Linear_systems/Linearisation.ipynb)
# * `sympy.simplify`: [Numeric representation](1_Dynamics/2_Time_domain_simulation/Numeric%20representation.ipynb), [Transfer function matrices](1_Dynamics/6_Multivariable_system_representation/Transfer%20function%20matrices.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb), [Decoupling](2_Control/7_Multivariable_control/Decoupling.ipynb), [Multivariable closed loop transfer functions](2_Control/7_Multivariable_control/Multivariable%20closed%20loop%20transfer%20functions.ipynb)
# * `sympy.sin`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb), [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb), [Sinusoidal response](1_Dynamics/4_First_and_second_order_system_dynamics/Sinusoidal%20response.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb)
# * `sympy.solve`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Extra Python](0_Getting_Started/Extra%20Python.ipynb), [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb), [Draining cup](1_Dynamics/1_Modelling/Draining%20cup.ipynb), [The blending system](1_Dynamics/1_Modelling/The%20blending%20system.ipynb), [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb), [Block diagram simplification](1_Dynamics/5_Complex_system_dynamics/Block%20diagram%20simplification.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb), [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb), [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb), [Example 10.11](2_Control/4_Frequency_domain_analysis_of_control_systems/Example%2010.11.ipynb), [Decoupling](2_Control/7_Multivariable_control/Decoupling.ipynb), [Symbolic tools](under_construction/Symbolic%20tools.ipynb)
# * `sympy.sqrt`: [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb), [Draining cup](1_Dynamics/1_Modelling/Draining%20cup.ipynb), [Numeric representation](1_Dynamics/2_Time_domain_simulation/Numeric%20representation.ipynb), [Sinusoidal response](1_Dynamics/4_First_and_second_order_system_dynamics/Sinusoidal%20response.ipynb)
# * `sympy.symbols`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Extra Python](0_Getting_Started/Extra%20Python.ipynb), [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb), [Draining cup](1_Dynamics/1_Modelling/Draining%20cup.ipynb), [The blending system](1_Dynamics/1_Modelling/The%20blending%20system.ipynb), [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb), [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb), [Linearisation](1_Dynamics/3_Linear_systems/Linearisation.ipynb), [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Second order systems](1_Dynamics/4_First_and_second_order_system_dynamics/Second%20order%20systems.ipynb), [Sinusoidal response](1_Dynamics/4_First_and_second_order_system_dynamics/Sinusoidal%20response.ipynb), [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Block diagram simplification](1_Dynamics/5_Complex_system_dynamics/Block%20diagram%20simplification.ipynb), [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb), [The z domain and continuous systems](1_Dynamics/9_Sampled_systems/The%20z%20domain%20and%20continuous%20systems.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb), [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb), [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb), [RQ tuning relations](2_Control/3_PID_controller_design_tuning_and_troubleshooting/RQ%20tuning%20relations.ipynb), [Example 10.11](2_Control/4_Frequency_domain_analysis_of_control_systems/Example%2010.11.ipynb), [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Decoupling](2_Control/7_Multivariable_control/Decoupling.ipynb), [Multivariable closed loop transfer functions](2_Control/7_Multivariable_control/Multivariable%20closed%20loop%20transfer%20functions.ipynb), [Multivariable stability analysis](2_Control/7_Multivariable_control/Multivariable%20stability%20analysis.ipynb), [IMC control design](under_construction/IMC%20control%20design.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb), [Triangular response](under_construction/Triangular%20response.ipynb)
# * `sympy.tan`: [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb)
# * `sympy.var`: [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb)
#
# # mpmath
#
# * `mpmath.cplot`: [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb)
# * `mpmath.fourier`: [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb)
# * `mpmath.fourierval`: [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb)
# * `mpmath.plot`: [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb)
#
# # pandas
#
# * `pandas.DataFrame`: [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb)
# * `pandas.DataFrame.from_records`: [TCLab PID](tclab/TCLab%20PID.ipynb)
# * `pandas.read_csv`: [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb), [Dealing with data](under_construction/Dealing%20with%20data.ipynb), [Fitting example](under_construction/Fitting%20example.ipynb)
# * `pandas.read_excel`: [Read input from file](1_Dynamics/2_Time_domain_simulation/Read%20input%20from%20file.ipynb), [Regression](1_Dynamics/7_System_identification/Regression.ipynb)
#
# # plt
#
# * `plt.axhline`: [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb), [Position vs velocity](tclab/Position%20vs%20velocity.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `plt.axis`: [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb), [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb), [Aliasing](1_Dynamics/9_Sampled_systems/Aliasing.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Eigenvalues and Eigenvectors](2_Control/7_Multivariable_control/Eigenvalues%20and%20Eigenvectors.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `plt.axvline`: [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `plt.figure`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Dynamic model parameter estimation](1_Dynamics/7_System_identification/Dynamic%20model%20parameter%20estimation.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb), [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb), [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb), [FOPDT fit](tclab/FOPDT%20fit.ipynb), [Position vs velocity](tclab/Position%20vs%20velocity.ipynb), [TCLab step test](tclab/TCLab%20step%20test.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `plt.grid`: [RQ Freq basics](2_Control/4_Frequency_domain_analysis_of_control_systems/RQ%20Freq%20basics.ipynb)
# * `plt.legend`: [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb), [Mixing system](1_Dynamics/2_Time_domain_simulation/Mixing%20system.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb), [Dynamic model parameter estimation](1_Dynamics/7_System_identification/Dynamic%20model%20parameter%20estimation.ipynb), [Regression](1_Dynamics/7_System_identification/Regression.ipynb), [Filtering](1_Dynamics/9_Sampled_systems/Filtering.ipynb), [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb), [RQ Freq basics](2_Control/4_Frequency_domain_analysis_of_control_systems/RQ%20Freq%20basics.ipynb), [Dead time compensation](2_Control/5_Advanced_control_methods/Dead%20time%20compensation.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb), [Blocksim](Simulation/Blocksim.ipynb), [Object-Oriented simulation](Simulation/Object-Oriented%20simulation.ipynb), [Difference Functions](under_construction/Difference%20Functions.ipynb)
# * `plt.loglog`: [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb)
# * `plt.pcolor`: [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb), [Multivariable stability analysis](2_Control/7_Multivariable_control/Multivariable%20stability%20analysis.ipynb)
# * `plt.plot`: [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb), [Mixing system](1_Dynamics/2_Time_domain_simulation/Mixing%20system.ipynb), [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb), [Read input from file](1_Dynamics/2_Time_domain_simulation/Read%20input%20from%20file.ipynb), [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb), [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb), [Dynamic model parameter estimation](1_Dynamics/7_System_identification/Dynamic%20model%20parameter%20estimation.ipynb), [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb), [Regression](1_Dynamics/7_System_identification/Regression.ipynb), [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb), [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb), [Aliasing](1_Dynamics/9_Sampled_systems/Aliasing.ipynb), [Filtering](1_Dynamics/9_Sampled_systems/Filtering.ipynb), [The z domain and continuous systems](1_Dynamics/9_Sampled_systems/The%20z%20domain%20and%20continuous%20systems.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [Control game](2_Control/1_Conventional_feedback_control/Control%20game.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [PID controller step responses](2_Control/1_Conventional_feedback_control/PID%20controller%20step%20responses.ipynb), [Solve IVP](2_Control/1_Conventional_feedback_control/Solve%20IVP.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb), [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb), [RQ Online controller tuning](2_Control/3_PID_controller_design_tuning_and_troubleshooting/RQ%20Online%20controller%20tuning.ipynb), [RQ tuning relations](2_Control/3_PID_controller_design_tuning_and_troubleshooting/RQ%20tuning%20relations.ipynb), [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb), [RQ Freq basics](2_Control/4_Frequency_domain_analysis_of_control_systems/RQ%20Freq%20basics.ipynb), [Dead time compensation](2_Control/5_Advanced_control_methods/Dead%20time%20compensation.ipynb), [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Noise models](2_Control/6_Discrete_control_and_analysis/Noise%20models.ipynb), [Eigenvalues and Eigenvectors](2_Control/7_Multivariable_control/Eigenvalues%20and%20Eigenvectors.ipynb), [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb), [Control valve design](2_Control/8_Control_Practice/Control%20valve%20design.ipynb), [Blocksim](Simulation/Blocksim.ipynb), [Hybrid system simulation](Simulation/Hybrid%20system%20simulation.ipynb), [Object-Oriented simulation - Discrete](Simulation/Object-Oriented%20simulation%20-%20Discrete.ipynb), [Object-Oriented simulation](Simulation/Object-Oriented%20simulation.ipynb), [Timing study](Simulation/Timing%20study.ipynb), [FOPDT fit](tclab/FOPDT%20fit.ipynb), [Frequency domain](tclab/Frequency%20domain.ipynb), [Position vs velocity](tclab/Position%20vs%20velocity.ipynb), [TCLab step test](tclab/TCLab%20step%20test.ipynb), [Difference Functions](under_construction/Difference%20Functions.ipynb), [Fitting example](under_construction/Fitting%20example.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb), [Overshoot from two first orders](under_construction/Overshoot%20from%20two%20first%20orders.ipynb), [Real time simulation](under_construction/Real%20time%20simulation.ipynb)
# * `plt.savefig`: [RQ Freq basics](2_Control/4_Frequency_domain_analysis_of_control_systems/RQ%20Freq%20basics.ipynb)
# * `plt.sca`: [Random response generator](1_Dynamics/5_Complex_system_dynamics/Random%20response%20generator.ipynb), [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `plt.scatter`: [Dynamic model parameter estimation](1_Dynamics/7_System_identification/Dynamic%20model%20parameter%20estimation.ipynb), [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb), [Regression](1_Dynamics/7_System_identification/Regression.ipynb), [Aliasing](1_Dynamics/9_Sampled_systems/Aliasing.ipynb), [Filtering](1_Dynamics/9_Sampled_systems/Filtering.ipynb), [Solve IVP](2_Control/1_Conventional_feedback_control/Solve%20IVP.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `plt.semilogx`: [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `plt.show`: [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Dynamic model parameter estimation](1_Dynamics/7_System_identification/Dynamic%20model%20parameter%20estimation.ipynb), [Eigenvalues and Eigenvectors](2_Control/7_Multivariable_control/Eigenvalues%20and%20Eigenvectors.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `plt.stem`: [The z domain and continuous systems](1_Dynamics/9_Sampled_systems/The%20z%20domain%20and%20continuous%20systems.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb)
# * `plt.subplot`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `plt.subplot2grid`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb), [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `plt.subplots`: [Fed batch bioreactor](1_Dynamics/2_Time_domain_simulation/Fed%20batch%20bioreactor.ipynb), [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb), [Random response generator](1_Dynamics/5_Complex_system_dynamics/Random%20response%20generator.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb), [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb), [Closed loop controlled responses](2_Control/1_Conventional_feedback_control/Closed%20loop%20controlled%20responses.ipynb), [Control game](2_Control/1_Conventional_feedback_control/Control%20game.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [RQ Freq basics](2_Control/4_Frequency_domain_analysis_of_control_systems/RQ%20Freq%20basics.ipynb), [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Simple discrete controller simulation](2_Control/6_Discrete_control_and_analysis/Simple%20discrete%20controller%20simulation.ipynb), [Continuous PID on TCLab](tclab/Continuous%20PID%20on%20TCLab.ipynb), [Frequency domain](tclab/Frequency%20domain.ipynb), [Using the FFT to approximate the frequency response](under_construction/Using%20the%20FFT%20to%20approximate%20the%20frequency%20response.ipynb)
# * `plt.text`: [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `plt.tight_layout`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Fed batch bioreactor](1_Dynamics/2_Time_domain_simulation/Fed%20batch%20bioreactor.ipynb)
# * `plt.title`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Root locus diagrams](2_Control/2_Laplace_domain_analysis_of_control_systems/Root%20locus%20diagrams.ipynb), [Position vs velocity](tclab/Position%20vs%20velocity.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `plt.twinx`: [Position vs velocity](tclab/Position%20vs%20velocity.ipynb)
# * `plt.xlabel`: [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb), [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb), [Multivariable stability analysis](2_Control/7_Multivariable_control/Multivariable%20stability%20analysis.ipynb), [Control valve design](2_Control/8_Control_Practice/Control%20valve%20design.ipynb), [Difference Functions](under_construction/Difference%20Functions.ipynb)
# * `plt.xlim`: [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb), [Frequency domain](tclab/Frequency%20domain.ipynb)
# * `plt.ylabel`: [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb), [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb), [Multivariable stability analysis](2_Control/7_Multivariable_control/Multivariable%20stability%20analysis.ipynb), [Control valve design](2_Control/8_Control_Practice/Control%20valve%20design.ipynb), [Difference Functions](under_construction/Difference%20Functions.ipynb)
# * `plt.ylim`: [Mixing system](1_Dynamics/2_Time_domain_simulation/Mixing%20system.ipynb), [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb), [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [Control valve design](2_Control/8_Control_Practice/Control%20valve%20design.ipynb), [FOPDT fit](tclab/FOPDT%20fit.ipynb), [Frequency domain](tclab/Frequency%20domain.ipynb), [Position vs velocity](tclab/Position%20vs%20velocity.ipynb), [TCLab step test](tclab/TCLab%20step%20test.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
#
# # control
#
# * `control.bode`: [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb)
# * `control.bode_plot`: [RQ Freq basics](2_Control/4_Frequency_domain_analysis_of_control_systems/RQ%20Freq%20basics.ipynb)
# * `control.feedback`: [RQ tuning relations](2_Control/3_PID_controller_design_tuning_and_troubleshooting/RQ%20tuning%20relations.ipynb)
# * `control.forced_response`: [Continuous PID on TCLab](tclab/Continuous%20PID%20on%20TCLab.ipynb)
# * `control.impulse_response`: [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb)
# * `control.nyquist_plot`: [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb)
# * `control.pzmap`: [Random response generator](1_Dynamics/5_Complex_system_dynamics/Random%20response%20generator.ipynb), [Root locus diagrams](2_Control/2_Laplace_domain_analysis_of_control_systems/Root%20locus%20diagrams.ipynb)
# * `control.rlocus`: [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb)
# * `control.root_locus`: [Root locus diagrams](2_Control/2_Laplace_domain_analysis_of_control_systems/Root%20locus%20diagrams.ipynb)
# * `control.ss`: [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb), [Transfer function matrices](1_Dynamics/6_Multivariable_system_representation/Transfer%20function%20matrices.ipynb)
# * `control.step_response`: [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Random response generator](1_Dynamics/5_Complex_system_dynamics/Random%20response%20generator.ipynb), [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb), [Dynamic model parameter estimation](1_Dynamics/7_System_identification/Dynamic%20model%20parameter%20estimation.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [Closed loop controlled responses](2_Control/1_Conventional_feedback_control/Closed%20loop%20controlled%20responses.ipynb), [PID controller step responses](2_Control/1_Conventional_feedback_control/PID%20controller%20step%20responses.ipynb), [RQ tuning relations](2_Control/3_PID_controller_design_tuning_and_troubleshooting/RQ%20tuning%20relations.ipynb), [Real time simulation](under_construction/Real%20time%20simulation.ipynb)
# * `control.tf`: [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Random response generator](1_Dynamics/5_Complex_system_dynamics/Random%20response%20generator.ipynb), [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb), [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb), [Transfer function matrices](1_Dynamics/6_Multivariable_system_representation/Transfer%20function%20matrices.ipynb), [Dynamic model parameter estimation](1_Dynamics/7_System_identification/Dynamic%20model%20parameter%20estimation.ipynb), [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [Closed loop controlled responses](2_Control/1_Conventional_feedback_control/Closed%20loop%20controlled%20responses.ipynb), [PID controller step responses](2_Control/1_Conventional_feedback_control/PID%20controller%20step%20responses.ipynb), [Root locus diagrams](2_Control/2_Laplace_domain_analysis_of_control_systems/Root%20locus%20diagrams.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb), [RQ tuning relations](2_Control/3_PID_controller_design_tuning_and_troubleshooting/RQ%20tuning%20relations.ipynb), [RQ Freq basics](2_Control/4_Frequency_domain_analysis_of_control_systems/RQ%20Freq%20basics.ipynb), [Overshoot from two first orders](under_construction/Overshoot%20from%20two%20first%20orders.ipynb), [Real time simulation](under_construction/Real%20time%20simulation.ipynb)
#
# # tclab
#
# * `tclab.Experiment`: [Position vs velocity](tclab/Position%20vs%20velocity.ipynb)
# * `tclab.Historian`: [Continuous PID on TCLab](tclab/Continuous%20PID%20on%20TCLab.ipynb), [Frequency domain](tclab/Frequency%20domain.ipynb)
# * `tclab.TCLabModel`: [Continuous PID on TCLab](tclab/Continuous%20PID%20on%20TCLab.ipynb)
# * `tclab.historian.TagDB`: [Position vs velocity](tclab/Position%20vs%20velocity.ipynb)
#
# # tbcontrol
#
# * `tbcontrol.conversion.discrete_coeffs_pos_to_neg`: [Simple discrete controller simulation](2_Control/6_Discrete_control_and_analysis/Simple%20discrete%20controller%20simulation.ipynb)
# * `tbcontrol.expectversion`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb), [Dynamic model parameter estimation](1_Dynamics/7_System_identification/Dynamic%20model%20parameter%20estimation.ipynb), [The z domain and continuous systems](1_Dynamics/9_Sampled_systems/The%20z%20domain%20and%20continuous%20systems.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Simple discrete controller simulation](2_Control/6_Discrete_control_and_analysis/Simple%20discrete%20controller%20simulation.ipynb), [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb), [Blocksim](Simulation/Blocksim.ipynb)
# * `tbcontrol.symbolic.evaluate_at_times`: [The z domain and continuous systems](1_Dynamics/9_Sampled_systems/The%20z%20domain%20and%20continuous%20systems.ipynb)
# * `tbcontrol.symbolic.linearise`: [Linearisation](1_Dynamics/3_Linear_systems/Linearisation.ipynb)
# * `tbcontrol.symbolic.pade`: [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb)
# * `tbcontrol.symbolic.sampledvalues`: [The z domain and continuous systems](1_Dynamics/9_Sampled_systems/The%20z%20domain%20and%20continuous%20systems.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb), [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb)
# * `tbcontrol.symbolic.ss2tf`: [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb)
#
# # blocksim
#
# * `blocksim.AlgebraicEquation`: [Blocksim](Simulation/Blocksim.ipynb)
# * `blocksim.Deadtime`: [Dead time compensation](2_Control/5_Advanced_control_methods/Dead%20time%20compensation.ipynb)
# * `blocksim.Diagram`: [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb), [RQ Online controller tuning](2_Control/3_PID_controller_design_tuning_and_troubleshooting/RQ%20Online%20controller%20tuning.ipynb), [Dead time compensation](2_Control/5_Advanced_control_methods/Dead%20time%20compensation.ipynb), [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb), [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb), [Blocksim](Simulation/Blocksim.ipynb)
# * `blocksim.DiscreteTF`: [Simple discrete controller simulation](2_Control/6_Discrete_control_and_analysis/Simple%20discrete%20controller%20simulation.ipynb)
# * `blocksim.LTI`: [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb), [RQ Online controller tuning](2_Control/3_PID_controller_design_tuning_and_troubleshooting/RQ%20Online%20controller%20tuning.ipynb), [Dead time compensation](2_Control/5_Advanced_control_methods/Dead%20time%20compensation.ipynb), [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb), [Simple discrete controller simulation](2_Control/6_Discrete_control_and_analysis/Simple%20discrete%20controller%20simulation.ipynb), [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb), [Blocksim](Simulation/Blocksim.ipynb)
# * `blocksim.PI`: [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb), [Dead time compensation](2_Control/5_Advanced_control_methods/Dead%20time%20compensation.ipynb), [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb), [Blocksim](Simulation/Blocksim.ipynb)
# * `blocksim.PID`: [Blocksim](Simulation/Blocksim.ipynb)
# * `blocksim.simple_control_diagram`: [Simple discrete controller simulation](2_Control/6_Discrete_control_and_analysis/Simple%20discrete%20controller%20simulation.ipynb)
# * `blocksim.step`: [RQ Online controller tuning](2_Control/3_PID_controller_design_tuning_and_troubleshooting/RQ%20Online%20controller%20tuning.ipynb), [Dead time compensation](2_Control/5_Advanced_control_methods/Dead%20time%20compensation.ipynb), [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb), [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb), [Blocksim](Simulation/Blocksim.ipynb)
#
# # Other
# * `A.eigenvals`: [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `A.inv`: [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `A.solve`: [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb)
# * `A.subs`: [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `Audio`: [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb)
# * `ControlGame`: [Control game](2_Control/1_Conventional_feedback_control/Control%20game.ipynb)
# * `DataFrame`: [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb)
# * `DiscreteController`: [Object-Oriented simulation - Discrete](Simulation/Object-Oriented%20simulation%20-%20Discrete.ipynb)
# * `F.apart`: [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb)
# * `Fin`: [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb), [Read input from file](1_Dynamics/2_Time_domain_simulation/Read%20input%20from%20file.ipynb)
# * `G`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb), [RQ Freq basics](2_Control/4_Frequency_domain_analysis_of_control_systems/RQ%20Freq%20basics.ipynb)
# * `G.det`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
# * `G.inv`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
# * `G.multiply_elementwise`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
# * `G.pole`: [Overshoot from two first orders](under_construction/Overshoot%20from%20two%20first%20orders.ipynb)
# * `G.sample`: [Simple discrete controller simulation](2_Control/6_Discrete_control_and_analysis/Simple%20discrete%20controller%20simulation.ipynb)
# * `G.step`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb)
# * `G.to_ss`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb), [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb)
# * `G.zero`: [Overshoot from two first orders](under_construction/Overshoot%20from%20two%20first%20orders.ipynb)
# * `G2.subs`: [Triangular response](under_construction/Triangular%20response.ipynb)
# * `G2.to_ss`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb)
# * `G2ss.to_tf`: [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb)
# * `G_CL.pole`: [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb)
# * `G_CL.subs`: [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb)
# * `G_C_rational.simplify`: [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb)
# * `G_p.adjugate`: [Decoupling](2_Control/7_Multivariable_control/Decoupling.ipynb)
# * `G_p.applyfunc`: [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb)
# * `G_p.inv`: [Decoupling](2_Control/7_Multivariable_control/Decoupling.ipynb)
# * `Gc.A.dot`: [Hybrid system simulation](Simulation/Hybrid%20system%20simulation.ipynb)
# * `Gc.B.dot`: [Hybrid system simulation](Simulation/Hybrid%20system%20simulation.ipynb)
# * `Gc.C.dot`: [Hybrid system simulation](Simulation/Hybrid%20system%20simulation.ipynb)
# * `Gc.D.dot`: [Hybrid system simulation](Simulation/Hybrid%20system%20simulation.ipynb)
# * `Gdc.minreal`: [Simple discrete controller simulation](2_Control/6_Discrete_control_and_analysis/Simple%20discrete%20controller%20simulation.ipynb)
# * `Gdiscrete.step`: [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb)
# * `Geval`: [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb)
# * `Gnumeric`: [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb)
# * `Gp`: [Dead time compensation](2_Control/5_Advanced_control_methods/Dead%20time%20compensation.ipynb)
# * `Gss.A.dot`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb)
# * `Gss.B.dot`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb)
# * `Gss.C.dot`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb)
# * `Gss.D.dot`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb)
# * `Gtf.pole`: [State space](1_Dynamics/6_Multivariable_system_representation/State%20space.ipynb)
# * `Gz.cancel`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb)
# * `Gz.expand`: [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb)
# * `Historian`: [FOPDT fit](tclab/FOPDT%20fit.ipynb)
# * `ISE.simplify`: [RQ tuning relations](2_Control/3_PID_controller_design_tuning_and_troubleshooting/RQ%20tuning%20relations.ipynb)
# * `K.multiply_elementwise`: [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb)
# * `L`: [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb)
# * `LHS.inv`: [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `MyClass`: [Classes](Simulation/Classes.ipynb)
# * `MyClass2`: [Classes](Simulation/Classes.ipynb)
# * `NotebookUI`: [TCLab PID](tclab/TCLab%20PID.ipynb)
# * `PIController`: [Object-Oriented simulation](Simulation/Object-Oriented%20simulation.ipynb)
# * `PIDpos`: [Position vs velocity](tclab/Position%20vs%20velocity.ipynb)
# * `PIDvel`: [Position vs velocity](tclab/Position%20vs%20velocity.ipynb)
# * `Person`: [Classes](Simulation/Classes.ipynb)
# * `R`: [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb)
# * `S`: [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb)
# * `S.plot`: [Fitting example](under_construction/Fitting%20example.ipynb)
# * `T.subs`: [Decoupling](2_Control/7_Multivariable_control/Decoupling.ipynb)
# * `TankSystem`: [Object-Oriented simulation - Discrete](Simulation/Object-Oriented%20simulation%20-%20Discrete.ipynb), [Object-Oriented simulation](Simulation/Object-Oriented%20simulation.ipynb)
# * `Tends.append`: [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb)
# * `TestClass`: [Special functions in classes](Simulation/Special%20functions%20in%20classes.ipynb)
# * `X.append`: [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb), [Difference Functions](under_construction/Difference%20Functions.ipynb)
# * `Y.append`: [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb), [Difference Functions](under_construction/Difference%20Functions.ipynb)
# * `a.__add__`: [Special functions in classes](Simulation/Special%20functions%20in%20classes.ipynb)
# * `annotated_bode`: [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `ax.axvline`: [Closed loop controlled responses](2_Control/1_Conventional_feedback_control/Closed%20loop%20controlled%20responses.ipynb), [Frequency domain](tclab/Frequency%20domain.ipynb)
# * `ax.plot`: [Closed loop controlled responses](2_Control/1_Conventional_feedback_control/Closed%20loop%20controlled%20responses.ipynb)
# * `axT.plot`: [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb)
# * `axT.set_ylabel`: [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb)
# * `ax_complex.axhline`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `ax_complex.axis`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Random response generator](1_Dynamics/5_Complex_system_dynamics/Random%20response%20generator.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `ax_complex.axvline`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `ax_complex.grid`: [Random response generator](1_Dynamics/5_Complex_system_dynamics/Random%20response%20generator.ipynb)
# * `ax_complex.plot`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `ax_complex.scatter`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `ax_complex.set_title`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb)
# * `ax_e.plot`: [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb)
# * `ax_e.set_ylabel`: [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb)
# * `ax_gain.axhline`: [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb), [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `ax_gain.axvline`: [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `ax_gain.loglog`: [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb), [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `ax_gain.set_ylabel`: [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb), [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `ax_gain.set_ylim`: [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb), [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `ax_impulse.plot`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb)
# * `ax_impulse.set_title`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb)
# * `ax_impulse.set_ylim`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb)
# * `ax_mag.loglog`: [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb)
# * `ax_phase.axhline`: [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb), [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `ax_phase.axvline`: [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `ax_phase.semilogx`: [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb), [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb), [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `ax_phase.set_xlabel`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `ax_phase.set_ylabel`: [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb), [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `ax_phase.set_ylim`: [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb)
# * `ax_step.axhline`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb)
# * `ax_step.plot`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb)
# * `ax_step.set_title`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb)
# * `ax_step.set_ylim`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb)
# * `ax_step.text`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb)
# * `ax_time.axhline`: [Random response generator](1_Dynamics/5_Complex_system_dynamics/Random%20response%20generator.ipynb)
# * `ax_time.plot`: [Random response generator](1_Dynamics/5_Complex_system_dynamics/Random%20response%20generator.ipynb)
# * `ax_u.plot`: [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Simple discrete controller simulation](2_Control/6_Discrete_control_and_analysis/Simple%20discrete%20controller%20simulation.ipynb)
# * `ax_u.set_ylabel`: [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Simple discrete controller simulation](2_Control/6_Discrete_control_and_analysis/Simple%20discrete%20controller%20simulation.ipynb)
# * `ax_u.set_ylim`: [Simple discrete controller simulation](2_Control/6_Discrete_control_and_analysis/Simple%20discrete%20controller%20simulation.ipynb)
# * `ax_y.axhline`: [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb)
# * `ax_y.plot`: [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Simple discrete controller simulation](2_Control/6_Discrete_control_and_analysis/Simple%20discrete%20controller%20simulation.ipynb)
# * `ax_y.set_ylabel`: [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Simple discrete controller simulation](2_Control/6_Discrete_control_and_analysis/Simple%20discrete%20controller%20simulation.ipynb)
# * `ax_y.set_ylim`: [Simple discrete controller simulation](2_Control/6_Discrete_control_and_analysis/Simple%20discrete%20controller%20simulation.ipynb)
# * `axcA.legend`: [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb)
# * `axcA.plot`: [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb)
# * `axcA.set_ylabel`: [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb)
# * `axcv.plot`: [Control game](2_Control/1_Conventional_feedback_control/Control%20game.ipynb)
# * `axgain.axvline`: [RQ Freq basics](2_Control/4_Frequency_domain_analysis_of_control_systems/RQ%20Freq%20basics.ipynb)
# * `axgain.grid`: [RQ Freq basics](2_Control/4_Frequency_domain_analysis_of_control_systems/RQ%20Freq%20basics.ipynb)
# * `axgain.loglog`: [RQ Freq basics](2_Control/4_Frequency_domain_analysis_of_control_systems/RQ%20Freq%20basics.ipynb), [Using the FFT to approximate the frequency response](under_construction/Using%20the%20FFT%20to%20approximate%20the%20frequency%20response.ipynb)
# * `axgain.set_ylabel`: [RQ Freq basics](2_Control/4_Frequency_domain_analysis_of_control_systems/RQ%20Freq%20basics.ipynb)
# * `axgain.text`: [Using the FFT to approximate the frequency response](under_construction/Using%20the%20FFT%20to%20approximate%20the%20frequency%20response.ipynb)
# * `axmv.plot`: [Control game](2_Control/1_Conventional_feedback_control/Control%20game.ipynb)
# * `axphase.axvline`: [RQ Freq basics](2_Control/4_Frequency_domain_analysis_of_control_systems/RQ%20Freq%20basics.ipynb)
# * `axphase.grid`: [RQ Freq basics](2_Control/4_Frequency_domain_analysis_of_control_systems/RQ%20Freq%20basics.ipynb)
# * `axphase.semilogx`: [RQ Freq basics](2_Control/4_Frequency_domain_analysis_of_control_systems/RQ%20Freq%20basics.ipynb), [Using the FFT to approximate the frequency response](under_construction/Using%20the%20FFT%20to%20approximate%20the%20frequency%20response.ipynb)
# * `axphase.set_xlabel`: [RQ Freq basics](2_Control/4_Frequency_domain_analysis_of_control_systems/RQ%20Freq%20basics.ipynb)
# * `axphase.set_ylabel`: [RQ Freq basics](2_Control/4_Frequency_domain_analysis_of_control_systems/RQ%20Freq%20basics.ipynb)
# * `axphase.set_yticks`: [RQ Freq basics](2_Control/4_Frequency_domain_analysis_of_control_systems/RQ%20Freq%20basics.ipynb)
# * `axphase.text`: [Using the FFT to approximate the frequency response](under_construction/Using%20the%20FFT%20to%20approximate%20the%20frequency%20response.ipynb)
# * `bigsymbolicA.solve`: [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb)
# * `bode`: [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb), [RQ Freq basics](2_Control/4_Frequency_domain_analysis_of_control_systems/RQ%20Freq%20basics.ipynb), [Frequency domain](tclab/Frequency%20domain.ipynb)
# * `bodegain`: [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb)
# * `carl.display_name`: [Classes](Simulation/Classes.ipynb)
# * `ce`: [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb)
# * `ce.expand`: [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb)
# * `chareq.as_numer_denom`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
# * `chareq.factor`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
# * `closedloop`: [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb)
# * `control_simulation`: [Object-Oriented simulation](Simulation/Object-Oriented%20simulation.ipynb)
# * `control_simulation_discrete`: [Object-Oriented simulation - Discrete](Simulation/Object-Oriented%20simulation%20-%20Discrete.ipynb)
# * `controller`: [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb)
# * `controller.change_input`: [Object-Oriented simulation](Simulation/Object-Oriented%20simulation.ipynb)
# * `controller.change_state`: [Object-Oriented simulation](Simulation/Object-Oriented%20simulation.ipynb)
# * `controller.run`: [Position vs velocity](tclab/Position%20vs%20velocity.ipynb)
# * `controller.update`: [Object-Oriented simulation - Discrete](Simulation/Object-Oriented%20simulation%20-%20Discrete.ipynb)
# * `cos`: [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb)
# * `cplot`: [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb)
# * `cross_axis`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `curve`: [Control valve design](2_Control/8_Control_Practice/Control%20valve%20design.ipynb)
# * `d.items`: [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `dMdt`: [Mixing system](1_Dynamics/2_Time_domain_simulation/Mixing%20system.ipynb)
# * `data.plot`: [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb)
# * `data.sort_index`: [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb)
# * `db.get_sessions`: [Position vs velocity](tclab/Position%20vs%20velocity.ipynb)
# * `decimal.Decimal`: [Numeric representation](1_Dynamics/2_Time_domain_simulation/Numeric%20representation.ipynb)
# * `denom.subs`: [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb)
# * `df.plot`: [Fitting example](under_construction/Fitting%20example.ipynb)
# * `dhdt`: [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb)
# * `diagram.simulate`: [RQ Online controller tuning](2_Control/3_PID_controller_design_tuning_and_troubleshooting/RQ%20Online%20controller%20tuning.ipynb), [Dead time compensation](2_Control/5_Advanced_control_methods/Dead%20time%20compensation.ipynb), [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb), [Simple discrete controller simulation](2_Control/6_Discrete_control_and_analysis/Simple%20discrete%20controller%20simulation.ipynb), [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb), [Blocksim](Simulation/Blocksim.ipynb)
# * `diagrams.items`: [Dead time compensation](2_Control/5_Advanced_control_methods/Dead%20time%20compensation.ipynb)
# * `dir`: [Special functions in classes](Simulation/Special%20functions%20in%20classes.ipynb)
# * `dsdt.append`: [Timing study](Simulation/Timing%20study.ipynb)
# * `enumerate`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Solve IVP](2_Control/1_Conventional_feedback_control/Solve%20IVP.ipynb), [Timing study](Simulation/Timing%20study.ipynb)
# * `eq.coeffs`: [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb)
# * `eq.diff`: [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb)
# * `error.__name__.upper`: [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb)
# * `errorint.set_ylabel`: [Closed loop controlled responses](2_Control/1_Conventional_feedback_control/Closed%20loop%20controlled%20responses.ipynb)
# * `errors.set_ylabel`: [Closed loop controlled responses](2_Control/1_Conventional_feedback_control/Closed%20loop%20controlled%20responses.ipynb)
# * `evalf`: [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `exp`: [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb)
# * `experiment.clock`: [Position vs velocity](tclab/Position%20vs%20velocity.ipynb)
# * `experiment.lab.Q1`: [Position vs velocity](tclab/Position%20vs%20velocity.ipynb)
# * `expz`: [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb)
# * `extend`: [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb)
# * `f`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Aliasing](1_Dynamics/9_Sampled_systems/Aliasing.ipynb), [Multivariable stability analysis](2_Control/7_Multivariable_control/Multivariable%20stability%20analysis.ipynb), [Classes](Simulation/Classes.ipynb), [Hybrid system simulation](Simulation/Hybrid%20system%20simulation.ipynb), [Numbers vs symbols](under_construction/Numbers%20vs%20symbols.ipynb), [Real time simulation](under_construction/Real%20time%20simulation.ipynb), [Symbolic tools](under_construction/Symbolic%20tools.ipynb)
# * `f.subs`: [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb)
# * `f.write`: [Dealing with data](under_construction/Dealing%20with%20data.ipynb)
# * `f2numeric`: [Visualising complex functions](1_Dynamics/3_Linear_systems/Visualising%20complex%20functions.ipynb)
# * `feedback`: [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb)
# * `filtersignal`: [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb)
# * `fin`: [Real time simulation](under_construction/Real%20time%20simulation.ipynb)
# * `firstorder`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb)
# * `fit_and_plot`: [Regression](1_Dynamics/7_System_identification/Regression.ipynb)
# * `fiterror`: [Regression](1_Dynamics/7_System_identification/Regression.ipynb)
# * `flat.append`: [Symbolic tools](under_construction/Symbolic%20tools.ipynb)
# * `float`: [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb), [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb), [Real time simulation](under_construction/Real%20time%20simulation.ipynb)
# * `fopdtitae.parameters`: [ITAE parameters for FOPDT system](2_Control/3_PID_controller_design_tuning_and_troubleshooting/ITAE%20parameters%20for%20FOPDT%20system.ipynb), [RQ tuning relations](2_Control/3_PID_controller_design_tuning_and_troubleshooting/RQ%20tuning%20relations.ipynb), [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb)
# * `frequencyplot`: [Sinusoidal response](1_Dynamics/4_First_and_second_order_system_dynamics/Sinusoidal%20response.ipynb)
# * `func`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
# * `fz.subs`: [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb)
# * `g.subs`: [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb)
# * `ga.set_ylim`: [Frequency domain](tclab/Frequency%20domain.ipynb)
# * `gainax.loglog`: [Frequency domain](tclab/Frequency%20domain.ipynb)
# * `gainax.scatter`: [Frequency domain](tclab/Frequency%20domain.ipynb)
# * `game.plot`: [Control game](2_Control/1_Conventional_feedback_control/Control%20game.ipynb)
# * `game.ui`: [Control game](2_Control/1_Conventional_feedback_control/Control%20game.ipynb)
# * `geval`: [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb)
# * `h`: [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb)
# * `h.get_sessions`: [FOPDT fit](tclab/FOPDT%20fit.ipynb), [Frequency domain](tclab/Frequency%20domain.ipynb)
# * `h.load_session`: [FOPDT fit](tclab/FOPDT%20fit.ipynb), [Frequency domain](tclab/Frequency%20domain.ipynb)
# * `help`: [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb)
# * `historian.to_csv`: [Continuous PID on TCLab](tclab/Continuous%20PID%20on%20TCLab.ipynb)
# * `historian.update`: [Continuous PID on TCLab](tclab/Continuous%20PID%20on%20TCLab.ipynb)
# * `hs.append`: [Hybrid system simulation](Simulation/Hybrid%20system%20simulation.ipynb)
# * `int`: [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb), [Simple discrete controller simulation](2_Control/6_Discrete_control_and_analysis/Simple%20discrete%20controller%20simulation.ipynb), [Classes](Simulation/Classes.ipynb), [Timing study](Simulation/Timing%20study.ipynb)
# * `interact`: [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Second order systems](1_Dynamics/4_First_and_second_order_system_dynamics/Second%20order%20systems.ipynb), [Sinusoidal response](1_Dynamics/4_First_and_second_order_system_dynamics/Sinusoidal%20response.ipynb), [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Random response generator](1_Dynamics/5_Complex_system_dynamics/Random%20response%20generator.ipynb), [Dynamic model parameter estimation](1_Dynamics/7_System_identification/Dynamic%20model%20parameter%20estimation.ipynb), [Asymptotic Bode diagrams](1_Dynamics/8_Frequency_domain/Asymptotic%20Bode%20diagrams.ipynb), [Aliasing](1_Dynamics/9_Sampled_systems/Aliasing.ipynb), [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb), [Root locus diagrams](2_Control/2_Laplace_domain_analysis_of_control_systems/Root%20locus%20diagrams.ipynb), [Stability analysis](2_Control/2_Laplace_domain_analysis_of_control_systems/Stability%20analysis.ipynb), [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb), [ITAE parameters for FOPDT system](2_Control/3_PID_controller_design_tuning_and_troubleshooting/ITAE%20parameters%20for%20FOPDT%20system.ipynb), [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb), [Eigenvalues and Eigenvectors](2_Control/7_Multivariable_control/Eigenvalues%20and%20Eigenvectors.ipynb), [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb), [Control valve design](2_Control/8_Control_Practice/Control%20valve%20design.ipynb), [Frequency domain](tclab/Frequency%20domain.ipynb), [Position vs velocity](tclab/Position%20vs%20velocity.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `interface.action_stop`: [TCLab PID](tclab/TCLab%20PID.ipynb)
# * `interface.historian.get_sessions`: [TCLab PID](tclab/TCLab%20PID.ipynb)
# * `interface.historian.load_session`: [TCLab PID](tclab/TCLab%20PID.ipynb)
# * `intsys`: [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb)
# * `invL`: [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb), [First order systems](1_Dynamics/4_First_and_second_order_system_dynamics/First%20order%20systems.ipynb), [Second order systems](1_Dynamics/4_First_and_second_order_system_dynamics/Second%20order%20systems.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb)
# * `itae`: [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb)
# * `keras.models.Sequential`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `l.append`: [Extra Python](0_Getting_Started/Extra%20Python.ipynb)
# * `lab.Q1`: [Continuous PID on TCLab](tclab/Continuous%20PID%20on%20TCLab.ipynb), [FOPDT fit](tclab/FOPDT%20fit.ipynb), [Frequency domain](tclab/Frequency%20domain.ipynb), [Position vs velocity](tclab/Position%20vs%20velocity.ipynb), [TCLab step test](tclab/TCLab%20step%20test.ipynb)
# * `lab.Q2`: [Continuous PID on TCLab](tclab/Continuous%20PID%20on%20TCLab.ipynb)
# * `lab.update`: [Continuous PID on TCLab](tclab/Continuous%20PID%20on%20TCLab.ipynb)
# * `len`: [Extra Python](0_Getting_Started/Extra%20Python.ipynb), [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb), [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb), [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb), [Symbolic tools](under_construction/Symbolic%20tools.ipynb)
# * `lim.subs`: [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb)
# * `limit`: [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb)
# * `lineq.subs`: [Linearisation](1_Dynamics/3_Linear_systems/Linearisation.ipynb)
# * `list`: [Extra Python](0_Getting_Started/Extra%20Python.ipynb), [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb)
# * `map`: [Regression](1_Dynamics/7_System_identification/Regression.ipynb)
# * `max`: [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb)
# * `model.add`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `model.compile`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `model.fit`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `moving`: [Filtering](1_Dynamics/9_Sampled_systems/Filtering.ipynb)
# * `multiple_equations`: [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb)
# * `my_solve_ivp`: [Real time simulation](under_construction/Real%20time%20simulation.ipynb)
# * `net.fit`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `network_output`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `noisy_and_original`: [Filtering](1_Dynamics/9_Sampled_systems/Filtering.ipynb)
# * `np.abs`: [Using the FFT to approximate the frequency response](under_construction/Using%20the%20FFT%20to%20approximate%20the%20frequency%20response.ipynb)
# * `np.arange`: [Using the FFT to approximate the frequency response](under_construction/Using%20the%20FFT%20to%20approximate%20the%20frequency%20response.ipynb)
# * `np.exp`: [Using the FFT to approximate the frequency response](under_construction/Using%20the%20FFT%20to%20approximate%20the%20frequency%20response.ipynb)
# * `np.fft.rfft`: [Using the FFT to approximate the frequency response](under_construction/Using%20the%20FFT%20to%20approximate%20the%20frequency%20response.ipynb)
# * `np.fft.rfftfreq`: [Using the FFT to approximate the frequency response](under_construction/Using%20the%20FFT%20to%20approximate%20the%20frequency%20response.ipynb)
# * `np.logspace`: [Using the FFT to approximate the frequency response](under_construction/Using%20the%20FFT%20to%20approximate%20the%20frequency%20response.ipynb)
# * `np.unwrap`: [Using the FFT to approximate the frequency response](under_construction/Using%20the%20FFT%20to%20approximate%20the%20frequency%20response.ipynb)
# * `num.collect`: [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb)
# * `numer.all_coeffs`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
# * `nyquist`: [Frequency response plots](1_Dynamics/8_Frequency_domain/Frequency%20response%20plots.ipynb)
# * `nyquistplot`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `objective`: [Control game](2_Control/1_Conventional_feedback_control/Control%20game.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb)
# * `open`: [Dealing with data](under_construction/Dealing%20with%20data.ipynb)
# * `outputs.append`: [Object-Oriented simulation - Discrete](Simulation/Object-Oriented%20simulation%20-%20Discrete.ipynb), [Object-Oriented simulation](Simulation/Object-Oriented%20simulation.ipynb)
# * `outputs.legend`: [Closed loop controlled responses](2_Control/1_Conventional_feedback_control/Closed%20loop%20controlled%20responses.ipynb)
# * `outputs.plot`: [Closed loop controlled responses](2_Control/1_Conventional_feedback_control/Closed%20loop%20controlled%20responses.ipynb)
# * `outputs.set_ylabel`: [Closed loop controlled responses](2_Control/1_Conventional_feedback_control/Closed%20loop%20controlled%20responses.ipynb)
# * `p.append`: [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb)
# * `p.extend`: [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb)
# * `p.show`: [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb)
# * `p1.extend`: [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb)
# * `p1.show`: [Fourier series](1_Dynamics/8_Frequency_domain/Fourier%20series.ipynb)
# * `pa.set_ylim`: [Frequency domain](tclab/Frequency%20domain.ipynb)
# * `pack`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `pade`: [Example 10.11](2_Control/4_Frequency_domain_analysis_of_control_systems/Example%2010.11.ipynb)
# * `parameters`: [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb)
# * `patsy.dmatrices`: [Regression](1_Dynamics/7_System_identification/Regression.ipynb)
# * `phaseax.scatter`: [Frequency domain](tclab/Frequency%20domain.ipynb)
# * `phaseax.semilogx`: [Frequency domain](tclab/Frequency%20domain.ipynb)
# * `plot_approx`: [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb)
# * `plot_continuous`: [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb)
# * `plot_discrete`: [The z domain and continuous systems](1_Dynamics/9_Sampled_systems/The%20z%20domain%20and%20continuous%20systems.ipynb)
# * `plot_outputs`: [Simple discrete controller simulation](2_Control/6_Discrete_control_and_analysis/Simple%20discrete%20controller%20simulation.ipynb)
# * `plot_step_response`: [PID controller step responses](2_Control/1_Conventional_feedback_control/PID%20controller%20step%20responses.ipynb)
# * `plotcomplex`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `plotdiscrete`: [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb)
# * `plotfit`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `plotfreqs`: [Frequency domain](tclab/Frequency%20domain.ipynb)
# * `plotoutput`: [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb)
# * `plotpz`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `plotresponse`: [Closed loop controlled responses](2_Control/1_Conventional_feedback_control/Closed%20loop%20controlled%20responses.ipynb), [Triangular response](under_construction/Triangular%20response.ipynb)
# * `plotsituation`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `plotstep`: [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb)
# * `plotvector`: [Eigenvalues and Eigenvectors](2_Control/7_Multivariable_control/Eigenvalues%20and%20Eigenvectors.ipynb)
# * `plus_two`: [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb)
# * `polynomial.diff`: [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb)
# * `polynomial.expand`: [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb)
# * `polynomial.integrate`: [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb)
# * `polyvalfromroots`: [Frequency domain stability](2_Control/4_Frequency_domain_analysis_of_control_systems/Frequency%20domain%20stability.ipynb)
# * `positive`: [Control valve design](2_Control/8_Control_Practice/Control%20valve%20design.ipynb)
# * `predict`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `prediction`: [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb)
# * `print`: [Extra Python](0_Getting_Started/Extra%20Python.ipynb), [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb), [Draining cup](1_Dynamics/1_Modelling/Draining%20cup.ipynb), [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb), [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb), [Control game](2_Control/1_Conventional_feedback_control/Control%20game.ipynb), [Solve IVP](2_Control/1_Conventional_feedback_control/Solve%20IVP.ipynb), [ITAE parameters for FOPDT system](2_Control/3_PID_controller_design_tuning_and_troubleshooting/ITAE%20parameters%20for%20FOPDT%20system.ipynb), [Optimal control - minimal integral measures](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Optimal%20control%20-%20minimal%20integral%20measures.ipynb), [Classes](Simulation/Classes.ipynb), [Frequency domain](tclab/Frequency%20domain.ipynb), [Position vs velocity](tclab/Position%20vs%20velocity.ipynb), [Matrix exponentials](under_construction/Matrix%20exponentials.ipynb), [Numbers vs symbols](under_construction/Numbers%20vs%20symbols.ipynb), [Real time simulation](under_construction/Real%20time%20simulation.ipynb)
# * `qpoly.all_coeffs`: [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb)
# * `qsubs`: [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb)
# * `queue.append`: [Position vs velocity](tclab/Position%20vs%20velocity.ipynb)
# * `queue.pop`: [Position vs velocity](tclab/Position%20vs%20velocity.ipynb)
# * `queue.reverse`: [Position vs velocity](tclab/Position%20vs%20velocity.ipynb)
# * `range`: [Extra Python](0_Getting_Started/Extra%20Python.ipynb), [Numeric representation](1_Dynamics/2_Time_domain_simulation/Numeric%20representation.ipynb), [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb), [Identifying discrete-time models](1_Dynamics/7_System_identification/Identifying%20discrete-time%20models.ipynb), [The z domain and continuous systems](1_Dynamics/9_Sampled_systems/The%20z%20domain%20and%20continuous%20systems.ipynb), [Control game](2_Control/1_Conventional_feedback_control/Control%20game.ipynb), [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb), [Dahlin controller](2_Control/6_Discrete_control_and_analysis/Dahlin%20controller.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Multivariable Pairing](2_Control/7_Multivariable_control/Multivariable%20Pairing.ipynb), [Timing study](Simulation/Timing%20study.ipynb), [Difference Functions](under_construction/Difference%20Functions.ipynb), [Fitting example](under_construction/Fitting%20example.ipynb), [Real time simulation](under_construction/Real%20time%20simulation.ipynb)
# * `regplot`: [Regression](1_Dynamics/7_System_identification/Regression.ipynb)
# * `residuals`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb)
# * `response`: [Sinusoidal response](1_Dynamics/4_First_and_second_order_system_dynamics/Sinusoidal%20response.ipynb)
# * `response.apart`: [Triangular response](under_construction/Triangular%20response.ipynb)
# * `result.append`: [Extra Python](0_Getting_Started/Extra%20Python.ipynb), [Noise models](2_Control/6_Discrete_control_and_analysis/Noise%20models.ipynb), [Real time simulation](under_construction/Real%20time%20simulation.ipynb)
# * `results.append`: [Fed batch bioreactor](1_Dynamics/2_Time_domain_simulation/Fed%20batch%20bioreactor.ipynb), [Position vs velocity](tclab/Position%20vs%20velocity.ipynb)
# * `routh`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [SymPy Routh Array](2_Control/2_Laplace_domain_analysis_of_control_systems/SymPy%20Routh%20Array.ipynb), [Example 10.11](2_Control/4_Frequency_domain_analysis_of_control_systems/Example%2010.11.ipynb), [Multivariable stability analysis](2_Control/7_Multivariable_control/Multivariable%20stability%20analysis.ipynb)
# * `runexperiment`: [FOPDT fit](tclab/FOPDT%20fit.ipynb), [Frequency domain](tclab/Frequency%20domain.ipynb), [TCLab step test](tclab/TCLab%20step%20test.ipynb)
# * `s.say_my_name`: [Classes](Simulation/Classes.ipynb)
# * `sampledvalues`: [Cheatsheet](0_Getting_Started/Cheatsheet.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb)
# * `savefig`: [RQ Freq basics](2_Control/4_Frequency_domain_analysis_of_control_systems/RQ%20Freq%20basics.ipynb)
# * `say_hello`: [Numbers vs symbols](under_construction/Numbers%20vs%20symbols.ipynb)
# * `score`: [Control game](2_Control/1_Conventional_feedback_control/Control%20game.ipynb)
# * `self.G.to_ss`: [Object-Oriented simulation](Simulation/Object-Oriented%20simulation.ipynb)
# * `self.Gss.A.dot`: [Object-Oriented simulation](Simulation/Object-Oriented%20simulation.ipynb)
# * `self.Gss.B.dot`: [Object-Oriented simulation](Simulation/Object-Oriented%20simulation.ipynb)
# * `self.Gss.C.dot`: [Object-Oriented simulation](Simulation/Object-Oriented%20simulation.ipynb)
# * `self.Gss.D.dot`: [Object-Oriented simulation](Simulation/Object-Oriented%20simulation.ipynb)
# * `self.change_input`: [Object-Oriented simulation - Discrete](Simulation/Object-Oriented%20simulation%20-%20Discrete.ipynb), [Object-Oriented simulation](Simulation/Object-Oriented%20simulation.ipynb)
# * `self.change_state`: [Object-Oriented simulation - Discrete](Simulation/Object-Oriented%20simulation%20-%20Discrete.ipynb), [Object-Oriented simulation](Simulation/Object-Oriented%20simulation.ipynb)
# * `self.f`: [Object-Oriented simulation - Discrete](Simulation/Object-Oriented%20simulation%20-%20Discrete.ipynb), [Object-Oriented simulation](Simulation/Object-Oriented%20simulation.ipynb)
# * `self.reset`: [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb), [Position vs velocity](tclab/Position%20vs%20velocity.ipynb)
# * `self.update`: [Position vs velocity](tclab/Position%20vs%20velocity.ipynb)
# * `setpoint`: [Continuous PID on TCLab](tclab/Continuous%20PID%20on%20TCLab.ipynb)
# * `shownotes`: [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb)
# * `sigmoid`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `sim`: [Control game](2_Control/1_Conventional_feedback_control/Control%20game.ipynb)
# * `simulate`: [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb), [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb)
# * `simulation_results.items`: [Blocksim](Simulation/Blocksim.ipynb)
# * `sin`: [Laplace transforms](1_Dynamics/3_Linear_systems/Laplace%20transforms.ipynb)
# * `sinefit`: [Frequency domain](tclab/Frequency%20domain.ipynb)
# * `sklearn.neural_network.MLPRegressor`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `skogestad_half`: [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb)
# * `smooth_1st`: [Difference Functions](under_construction/Difference%20Functions.ipynb)
# * `sol.sol`: [Solve IVP](2_Control/1_Conventional_feedback_control/Solve%20IVP.ipynb)
# * `song.sum`: [Sound and frequency](1_Dynamics/8_Frequency_domain/Sound%20and%20frequency.ipynb)
# * `sopdt`: [Filtering](1_Dynamics/9_Sampled_systems/Filtering.ipynb)
# * `ss`: [Nonlinear CSTR](1_Dynamics/2_Time_domain_simulation/Nonlinear%20CSTR.ipynb)
# * `statehistory.append`: [Timing study](Simulation/Timing%20study.ipynb)
# * `steptimer.start`: [TCLab PID](tclab/TCLab%20PID.ipynb)
# * `steptimer.stop`: [TCLab PID](tclab/TCLab%20PID.ipynb)
# * `sum`: [Numeric representation](1_Dynamics/2_Time_domain_simulation/Numeric%20representation.ipynb), [Standard process inputs](1_Dynamics/4_First_and_second_order_system_dynamics/Standard%20process%20inputs.ipynb), [Regression](1_Dynamics/7_System_identification/Regression.ipynb), [Control game](2_Control/1_Conventional_feedback_control/Control%20game.ipynb), [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb), [Simple MPC](2_Control/7_Multivariable_control/Simple%20MPC.ipynb), [Frequency domain](tclab/Frequency%20domain.ipynb), [Triangular response](under_construction/Triangular%20response.ipynb)
# * `system.change_input`: [Object-Oriented simulation - Discrete](Simulation/Object-Oriented%20simulation%20-%20Discrete.ipynb), [Object-Oriented simulation](Simulation/Object-Oriented%20simulation.ipynb)
# * `system.change_state`: [Object-Oriented simulation - Discrete](Simulation/Object-Oriented%20simulation%20-%20Discrete.ipynb), [Object-Oriented simulation](Simulation/Object-Oriented%20simulation.ipynb)
# * `tablefunction`: [ITAE parameters for FOPDT system](2_Control/3_PID_controller_design_tuning_and_troubleshooting/ITAE%20parameters%20for%20FOPDT%20system.ipynb)
# * `taylor`: [Approximation](1_Dynamics/5_Complex_system_dynamics/Approximation.ipynb)
# * `temp.removeO`: [Notebook introduction](0_Getting_Started/Notebook%20introduction.ipynb)
# * `time.sleep`: [Real time simulation](under_construction/Real%20time%20simulation.ipynb)
# * `time.time`: [Real time simulation](under_construction/Real%20time%20simulation.ipynb)
# * `tornado.ioloop.PeriodicCallback`: [TCLab PID](tclab/TCLab%20PID.ipynb)
# * `tqdm`: [Continuous PID on TCLab](tclab/Continuous%20PID%20on%20TCLab.ipynb)
# * `type`: [Extra Python](0_Getting_Started/Extra%20Python.ipynb), [Numeric representation](1_Dynamics/2_Time_domain_simulation/Numeric%20representation.ipynb), [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb), [Classes](Simulation/Classes.ipynb), [Symbolic tools](under_construction/Symbolic%20tools.ipynb)
# * `u`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb), [Fitting example](under_construction/Fitting%20example.ipynb)
# * `u.set_ylabel`: [Closed loop controlled responses](2_Control/1_Conventional_feedback_control/Closed%20loop%20controlled%20responses.ipynb)
# * `u.subs`: [Convolution](1_Dynamics/3_Linear_systems/Convolution.ipynb)
# * `u_continuous.append`: [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb)
# * `u_discrete.append`: [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb)
# * `uaxis.plot`: [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb)
# * `uaxis.set_ylabel`: [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb)
# * `unitstep.doit`: [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb)
# * `unpack`: [Neural networks](1_Dynamics/7_System_identification/Neural%20networks.ipynb)
# * `unsolvable_numeric`: [Equation solving tools](1_Dynamics/2_Time_domain_simulation/Equation%20solving%20tools.ipynb)
# * `xs.append`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb)
# * `y_continuous.append`: [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb)
# * `y_discrete.append`: [Discrete control](2_Control/6_Discrete_control_and_analysis/Discrete%20control.ipynb)
# * `y_func`: [Effect of Proportional Control](2_Control/1_Conventional_feedback_control/Effect%20of%20Proportional%20Control.ipynb)
# * `yaxis.legend`: [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb)
# * `yaxis.plot`: [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb)
# * `yaxis.set_ylabel`: [Discrete PI](2_Control/6_Discrete_control_and_analysis/Discrete%20PI.ipynb)
# * `ypred.append`: [Fitting example](under_construction/Fitting%20example.ipynb)
# * `ys.append`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb)
# * `ys_statespace.append`: [Simulation of arbitrary transfer functions](1_Dynamics/5_Complex_system_dynamics/Simulation%20of%20arbitrary%20transfer%20functions.ipynb)
# * `yz.subs`: [The z transform](1_Dynamics/9_Sampled_systems/The%20z%20transform.ipynb)
# * `zeroeq.as_numer_denom`: [Direct synthesis PID design](2_Control/3_PID_controller_design_tuning_and_troubleshooting/Direct%20synthesis%20PID%20design.ipynb)
# * `zip`: [Extra Python](0_Getting_Started/Extra%20Python.ipynb), [Fed batch bioreactor](1_Dynamics/2_Time_domain_simulation/Fed%20batch%20bioreactor.ipynb), [ITAE parameters for FOPDT system](2_Control/3_PID_controller_design_tuning_and_troubleshooting/ITAE%20parameters%20for%20FOPDT%20system.ipynb), [Position vs velocity](tclab/Position%20vs%20velocity.ipynb)
