# %%
import sympy
sympy.init_printing()

# %%
x = 1
y = x + 1

# %%
y
# Out:
# 2

# %%
x = sympy.Symbol('x')

# %%
sympy.expand((x + 1)**5)
# Out:
#  5      4       3       2
# x  + 5⋅x  + 10⋅x  + 10⋅x  + 5⋅x + 1

# %%
r1, r2, r3 = sympy.solve(x**3 + x + 3, x)

# %%
sympy.N(r1)
# Out:
# 0.606705831381115 + 1.45061224918844⋅ⅈ

# %%
y = sympy.Symbol('y')

# %%
sol = sympy.solve([x + 2*y - 2,
                   2*x + y], [x, y])

# %%
type(sol)
# Out:
# dict

# %%
sol
# Out:
# {x: -2/3, y: 4/3}

# %%
sol[x]
# Out:
# -2/3

# %%
lst = [1, 2, 3]

# %%
dct = {'a': 1, 'b': 6}

# %%
dct
# Out:
# {'a': 1, 'b': 6}

# %%
[[x1, y1], [x2, y2]] = sol
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-021d89936c38> in <module>()
# ----> 1 [[x1, y1], [x2, y2]] = sol
#
# TypeError: 'Symbol' object is not iterable

# %%
type(sol)

# %%
len(sol)

# %%
flat = []
for s in sol:
    flat.append(sympy.N(s))

# %%
flat

# %%
[sympy.N(s) for s in sol]

# %%
def f(x):
    a, b, c = x
    
    return a + b*c

# %%
f([1, 2, 3])

# %%
lst = [[1, 2], 3]

# %%
a = lst[0][0]
b = lst[0][1]
c = lst[1]

# %%
[[a, b], c] = lst

# %%
sympy.N(sympy.sqrt(2))
