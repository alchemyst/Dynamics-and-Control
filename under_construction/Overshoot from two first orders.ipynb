# %%
import control

# %%
s = control.tf([1, 0], 1)

# %%
G = 1/(s + 1) - 0.4/(2*s + 1)

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.plot(*control.step_response(G))

# %%
G.zero()
# Out:
# array([-0.375])

# %%
G.pole()
# Out:
# array([-1. , -0.5])

# %%
# !open .
